# %% [markdown]
# # NB_11_trial_slow_batch_runner - Trial Batch Runner - Slow-Drive Subtrials
#
# **Purpose.** Sweep every trial and run a slow subtrial with a constant speed multiplier (e.g. v' = 0.85 v). Provides a non-risk-aware baseline that simply drives more conservatively.
#
# **Inputs.** trials authored with NB_08.
#
# **Outputs.** runs/<timestamp>_slow/ folders and a batch summary.
#
# **How to run.** Set SPEED_FACTOR in section 3, then run section 4 to execute the sweep.
#
# **Position in the workflow.** Conservative-baseline counterpart to NB_10. Compared in NB_15.

# %% [markdown]
# ## 0 — CARLA Launch
# Skip if CARLA is already running.

# %%
import subprocess

AUTO_LAUNCH_CARLA = True
CARLA_EXE = "CarlaUE4.exe"

if AUTO_LAUNCH_CARLA:
    subprocess.Popen(CARLA_EXE, shell=True)
    print(f"Launched {CARLA_EXE}")
else:
    print("AUTO_LAUNCH_CARLA is False. Assuming CARLA is already running.")
# Out:
# Launched CarlaUE4.exe

# %% [markdown]
# ## 1 — Imports

# %%
import sys
import time
from pathlib import Path

from MIREIA.config import Config
from MIREIA.simulation.trials import EgoTrialConfig, TrialDefinition, TrialRunner

# %% [markdown]
# ## 2 — Discover Trials
# Lists every `trial.json` under `PATH_TO_TRIALS`. Use `INCLUDE_PREFIXES` / `EXCLUDE_TRIALS` to limit the run.

# %%
trials_root = Path(Config.PATH_TO_TRIALS)
all_trials = sorted(p.parent.name for p in trials_root.glob("*/trial.json") if p.is_file())

# Filtering (leave INCLUDE_PREFIXES empty to include every trial)
INCLUDE_PREFIXES: list[str] = []   # e.g. ["auto_"] to only run auto-generated trials
EXCLUDE_TRIALS:   list[str] = []   # exact trial names to skip

if INCLUDE_PREFIXES:
    selected_trial_names = [n for n in all_trials if any(n.startswith(p) for p in INCLUDE_PREFIXES)]
else:
    selected_trial_names = list(all_trials)
selected_trial_names = [n for n in selected_trial_names if n not in EXCLUDE_TRIALS]

print(f"Found {len(all_trials)} trial(s); {len(selected_trial_names)} selected to run:")
for n in selected_trial_names:
    print(f"  - {n}")
# Out:
# Found 20 trial(s); 20 selected to run:
#   - auto_17A_WetNoon_Town05_HighVol
#   - auto_17B_WetNoon_Town05_LowVol
#   - auto_17C_WetNoon_Town10HD_HighVol
#   - auto_17D_WetNoon_Town10HD_LowVol
#   - auto_18A_MidRainyNoon_Town05_HighVol
#   - auto_18B_MidRainyNoon_Town05_LowVol
#   - auto_18C_MidRainyNoon_Town10HD_HighVol
#   - auto_18D_MidRainyNoon_Town10HD_LowVol
#   - auto_19A_CloudySunset_Town05_HighVol
#   - auto_19B_CloudySunset_Town05_LowVol
#   - auto_19C_CloudySunset_Town10HD_HighVol
#   - auto_19D_CloudySunset_Town10HD_LowVol
#   - auto_20A_SoftRainSunset_Town05_HighVol
#   - auto_20B_SoftRainSunset_Town05_LowVol
#   - auto_20C_SoftRainSunset_Town10HD_HighVol
#   - auto_20D_SoftRainSunset_Town10HD_LowVol
#   - auto_21A_ClearNoon_Town05_HighVol_NoFog_Night
#   - auto_21B_CloudyNoon_Town05_LowVol_NoFog_Night
#   - auto_21C_WetNoon_Town10HD_HighVol_NoFog_Night
#   - auto_21D_HardRainNoon_Town10HD_LowVol_NoFog_Night

# %% [markdown]
# ## 3 — Slow Subtrial Config
# `speed_multiplier = SPEED_FACTOR` is the constant function applied to the base target speed every tick. With `target_speed_kmh=None` (default — inherited from `EgoTrialConfig`), the base target is the **live zone speed limit** read from CARLA, so the slow run drives at `SPEED_FACTOR × zone_limit` per zone. Subtrial folder name is `slow`, so each run lands at `runs/<timestamp>_slow/`. Adjust `SPEED_FACTOR` to use a different constant (e.g. 0.5, 0.8).

# %%
SPEED_FACTOR        = 0.85   # v' = SPEED_FACTOR * v  (set to any constant <= 1.0 typically)
MAX_STEPS_PER_TRIAL = 6000   # hard cap; routes that take longer with the slow speed need a higher cap

slow_ego_cfg = EgoTrialConfig(
    name="half_slow",
    ego_blueprint="vehicle.lincoln.mkz_2020",
    # target_speed_kmh left at the default None so the controller uses the live
    # zone speed limit as the base v; v' = SPEED_FACTOR * zone_limit per tick.
    speed_multiplier=SPEED_FACTOR,
    use_vehicle_camera_defaults=True,
    controller_mode="behavior_agent",
    controller_behavior="normal",
)

runner = TrialRunner(verbose=False)
print(f"Slow ego config ready: zone-aware base speed × speed_multiplier={SPEED_FACTOR}")
# Out:
# Slow ego config ready: zone-aware base speed × speed_multiplier=0.85

# %% [markdown]
# ## 4 — Run Each Trial
# JSONL-only: `store_rgb_images=False` skips PNG writes (RGB / topdown / risk frame), `draw_debug_every_tick=False` skips CARLA debug overlays. World still ticks each step and `dataset.jsonl` still receives one record every `RECORD_EVERY_N_TICKS` ticks.
#
# Failures don't abort the batch — they're recorded and reported at the end.

# %%
all_summaries = []
failed: list[tuple[str, str]] = []

# --- Run-time accounting (sim vs wall, cap meaning) ----------------------------
# step  = one CARLA world.tick() = one fixed_delta seconds of simulated time.
# image_stride controls JSONL cadence, NOT loop iteration count.
# The loop exits early when controller.done() — ego reached the route end (within
# arrival_threshold_m = 3 m). max_steps is the cap; with SPEED_FACTOR < 1 the same
# route covers the same distance in MORE sim time, so a higher cap may be needed.
fixed_delta_s    = float(Config.SIM_FIXED_DELTA_SECONDS)
stride_ticks     = int(Config.RECORD_EVERY_N_TICKS)
sim_time_cap_s   = MAX_STEPS_PER_TRIAL * fixed_delta_s
max_jsonl_frames = MAX_STEPS_PER_TRIAL // stride_ticks
record_hz        = 1.0 / (fixed_delta_s * stride_ticks)

print("Run configuration:")
print(f"  speed_multiplier:     {SPEED_FACTOR:.3f}  (slow run)")
print(f"  fixed_delta:          {fixed_delta_s:.3f} s/tick  ({1/fixed_delta_s:.1f} Hz physics)")
print(f"  image_stride:         {stride_ticks} ticks/frame  ({record_hz:.2f} Hz JSONL records)")
print(f"  max_steps_per_trial:  {MAX_STEPS_PER_TRIAL}  (cap = {sim_time_cap_s:.1f} s sim time, "
      f"<= {max_jsonl_frames} JSONL frames)")
print(f"  finished=True   -> controller reported done before the cap (good)")
print(f"  finished=False  -> hit max_steps cap (raise MAX_STEPS_PER_TRIAL or increase SPEED_FACTOR)")

_progress_state: dict = {"trial_started": 0.0}

def _format_secs(s: float) -> str:
    if s < 60:
        return f"{s:5.1f}s"
    m, sec = divmod(s, 60)
    return f"{int(m):02d}:{int(sec):02d}"

def _on_progress(step: int, max_steps: int) -> None:
    now = time.time()
    last = _progress_state.get("last_print", 0.0)
    if now - last < 0.2:
        return
    _progress_state["last_print"] = now
    elapsed = now - _progress_state["trial_started"]
    rate = step / elapsed if elapsed > 0 else 0.0
    pct = 100.0 * step / max_steps if max_steps else 0.0
    eta_to_cap = (max_steps - step) / rate if rate > 0 else float("inf")
    speedup = (step * fixed_delta_s) / elapsed if elapsed > 0 else 0.0
    sys.stdout.write(
        f"\r    step {step:5d}/{max_steps} ({pct:5.1f}% of cap)  "
        f"wall={_format_secs(elapsed)}  "
        f"rate={rate:5.1f} t/s  "
        f"speedup={speedup:4.2f}x  "
        f"eta_to_cap={_format_secs(eta_to_cap) if rate > 0 else '  inf'}    "
    )
    sys.stdout.flush()

batch_started = time.time()
for idx, trial_name in enumerate(selected_trial_names, start=1):
    print()
    print(f">>> [{idx}/{len(selected_trial_names)}] {trial_name}", flush=True)
    _progress_state["trial_started"] = time.time()
    _progress_state["last_print"] = 0.0
    try:
        trial = TrialDefinition.load(trial_name)
        summary = runner.run_subtrial(
            trial=trial,
            ego_cfg=slow_ego_cfg,
            max_steps=MAX_STEPS_PER_TRIAL,
            image_stride=Config.RECORD_EVERY_N_TICKS,
            store_rgb_images=False,
            store_topdown_images=False,
            store_risk_frame_images=False,
            store_static_risk_map=False,
            draw_debug_every_tick=False,
            progress_callback=_on_progress,
            progress_every_n_steps=25,
        )
        elapsed = time.time() - _progress_state["trial_started"]
        sim_seconds = summary.num_frames * fixed_delta_s * stride_ticks
        speedup = sim_seconds / elapsed if elapsed > 0 else float("inf")
        sys.stdout.write("\r" + " " * 130 + "\r")
        sys.stdout.flush()
        print(
            f"    ok in {elapsed:6.1f}s wall  "
            f"frames={summary.num_frames:4d}  "
            f"sim_t={sim_seconds:6.1f}s  "
            f"speedup={speedup:5.2f}x  "
            f"dist={summary.traveled_m:7.1f}m  "
            f"risk_auc={summary.risk_auc:.3f}  "
            f"finished={summary.finished}"
        )
        all_summaries.append(summary)
    except Exception as e:
        elapsed = time.time() - _progress_state["trial_started"]
        sys.stdout.write("\r" + " " * 130 + "\r")
        sys.stdout.flush()
        print(f"    FAILED in {elapsed:.1f}s: {type(e).__name__}: {e}")
        failed.append((trial_name, f"{type(e).__name__}: {e}"))

batch_elapsed = time.time() - batch_started
print()
print(f"Batch done in {batch_elapsed:.1f}s (ok={len(all_summaries)}, failed={len(failed)})")
# Out:
# Run configuration:
#   speed_multiplier:     0.850  (slow run)
#   fixed_delta:          0.050 s/tick  (20.0 Hz physics)
#   image_stride:         5 ticks/frame  (4.00 Hz JSONL records)
#   max_steps_per_trial:  6000  (cap = 300.0 s sim time, <= 1200 JSONL frames)
#   finished=True   -> controller reported done before the cap (good)
#   finished=False  -> hit max_steps cap (raise MAX_STEPS_PER_TRIAL or increase SPEED_FACTOR)
#
# >>> [1/20] auto_17A_WetNoon_Town05_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step  1975/6000 ( 32.9% of cap)  wall=01:22  rate= 24.0 t/s  speedup=1.20x  eta_to_cap=02:47     Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in   83.0s wall  frames= 399  sim_t=  99.8s  speedup= 1.20x  dist=  544.8m  risk_auc=236.720  finished=True
#
# >>> [2/20] auto_17B_WetNoon_Town05_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step   750/6000 ( 12.5% of cap)  wall= 25.4s  rate= 29.5 t/s  speedup=1.48x  eta_to_cap=02:57    Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   25.6s wall  frames= 152  sim_t=  38.0s  speedup= 1.48x  dist=  561.7m  risk_auc=68.831  finished=True
#
# >>> [3/20] auto_17C_WetNoon_Town10HD_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step  1225/6000 ( 20.4% of cap)  wall= 56.7s  rate= 21.6 t/s  speedup=1.08x  eta_to_cap=03:40    Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in   57.7s wall  frames= 250  sim_t=  62.5s  speedup= 1.08x  dist=  160.0m  risk_auc=151.172  finished=True
#
# >>> [4/20] auto_17D_WetNoon_Town10HD_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  3200/6000 ( 53.3% of cap)  wall=01:14  rate= 42.9 t/s  speedup=2.15x  eta_to_cap=01:05     Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   75.0s wall  frames= 644  sim_t= 161.0s  speedup= 2.15x  dist=  423.0m  risk_auc=365.009  finished=True
#
# >>> [5/20] auto_18A_MidRainyNoon_Town05_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step  5525/6000 ( 92.1% of cap)  wall=03:31  rate= 26.1 t/s  speedup=1.30x  eta_to_cap= 18.2s    Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  212.5s wall  frames=1109  sim_t= 277.2s  speedup= 1.30x  dist=  950.2m  risk_auc=1292.148  finished=True
#
# >>> [6/20] auto_18B_MidRainyNoon_Town05_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step  1750/6000 ( 29.2% of cap)  wall= 44.1s  rate= 39.7 t/s  speedup=1.99x  eta_to_cap=01:46    Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   44.2s wall  frames= 351  sim_t=  87.8s  speedup= 1.99x  dist=  374.0m  risk_auc=497.841  finished=True
#
# >>> [7/20] auto_18C_MidRainyNoon_Town10HD_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step  5975/6000 ( 99.6% of cap)  wall=04:05  rate= 24.4 t/s  speedup=1.22x  eta_to_cap=  1.0s    Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  246.3s wall  frames=1200  sim_t= 300.0s  speedup= 1.22x  dist=  120.9m  risk_auc=767.846  finished=False
#
# >>> [8/20] auto_18D_MidRainyNoon_Town10HD_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  1925/6000 ( 32.1% of cap)  wall= 50.8s  rate= 37.9 t/s  speedup=1.90x  eta_to_cap=01:47    Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   50.9s wall  frames= 386  sim_t=  96.5s  speedup= 1.90x  dist=  312.5m  risk_auc=402.897  finished=True
#
# >>> [9/20] auto_19A_CloudySunset_Town05_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step   975/6000 ( 16.2% of cap)  wall= 47.7s  rate= 20.4 t/s  speedup=1.02x  eta_to_cap=04:05    Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in   48.4s wall  frames= 199  sim_t=  49.8s  speedup= 1.03x  dist=  152.9m  risk_auc=116.709  finished=True
#
# >>> [10/20] auto_19B_CloudySunset_Town05_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step  3975/6000 ( 66.2% of cap)  wall=01:32  rate= 42.9 t/s  speedup=2.14x  eta_to_cap= 47.2s    Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   92.9s wall  frames= 796  sim_t= 199.0s  speedup= 2.14x  dist=  861.8m  risk_auc=468.167  finished=True
#
# >>> [11/20] auto_19C_CloudySunset_Town10HD_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step  5975/6000 ( 99.6% of cap)  wall=04:12  rate= 23.7 t/s  speedup=1.18x  eta_to_cap=  1.1s    Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  253.4s wall  frames=1200  sim_t= 300.0s  speedup= 1.18x  dist=  654.4m  risk_auc=787.867  finished=False
#
# >>> [12/20] auto_19D_CloudySunset_Town10HD_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  1425/6000 ( 23.8% of cap)  wall= 41.3s  rate= 34.5 t/s  speedup=1.73x  eta_to_cap=02:12    Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   41.8s wall  frames= 290  sim_t=  72.5s  speedup= 1.73x  dist=  324.5m  risk_auc=195.529  finished=True
#
# >>> [13/20] auto_20A_SoftRainSunset_Town05_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step  3000/6000 ( 50.0% of cap)  wall=02:11  rate= 22.8 t/s  speedup=1.14x  eta_to_cap=02:11     Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  132.0s wall  frames= 602  sim_t= 150.5s  speedup= 1.14x  dist=  478.1m  risk_auc=610.286  finished=True
#
# >>> [14/20] auto_20B_SoftRainSunset_Town05_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step  4800/6000 ( 80.0% of cap)  wall=01:47  rate= 44.8 t/s  speedup=2.24x  eta_to_cap= 26.8s    Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in  107.6s wall  frames= 963  sim_t= 240.8s  speedup= 2.24x  dist=  997.7m  risk_auc=609.162  finished=True
#
# >>> [15/20] auto_20C_SoftRainSunset_Town10HD_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step  2950/6000 ( 49.2% of cap)  wall=02:07  rate= 23.1 t/s  speedup=1.15x  eta_to_cap=02:12     Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  128.6s wall  frames= 594  sim_t= 148.5s  speedup= 1.15x  dist=  719.9m  risk_auc=636.836  finished=True
#
# >>> [16/20] auto_20D_SoftRainSunset_Town10HD_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  3225/6000 ( 53.8% of cap)  wall=01:18  rate= 40.9 t/s  speedup=2.05x  eta_to_cap=01:07     Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   79.3s wall  frames= 650  sim_t= 162.5s  speedup= 2.05x  dist=  669.1m  risk_auc=460.822  finished=True
#
# >>> [17/20] auto_21A_ClearNoon_Town05_HighVol_NoFog_Night
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=True)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step  5975/6000 ( 99.6% of cap)  wall=04:46  rate= 20.9 t/s  speedup=1.04x  eta_to_cap=  1.2s    Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  287.7s wall  frames=1200  sim_t= 300.0s  speedup= 1.04x  dist= 1096.7m  risk_auc=662.621  finished=False
#
# >>> [18/20] auto_21B_CloudyNoon_Town05_LowVol_NoFog_Night
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=True)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step  2525/6000 ( 42.1% of cap)  wall=01:37  rate= 25.9 t/s  speedup=1.29x  eta_to_cap=02:14     Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   98.3s wall  frames= 510  sim_t= 127.5s  speedup= 1.30x  dist=  260.5m  risk_auc=261.295  finished=True
#
# >>> [19/20] auto_21C_WetNoon_Town10HD_HighVol_NoFog_Night
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=True)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step   975/6000 ( 16.2% of cap)  wall= 59.7s  rate= 16.3 t/s  speedup=0.82x  eta_to_cap=05:07    Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in   60.7s wall  frames= 199  sim_t=  49.8s  speedup= 0.82x  dist=  271.7m  risk_auc=182.573  finished=True
#
# >>> [20/20] auto_21D_HardRainNoon_Town10HD_LowVol_NoFog_Night
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=True)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  2750/6000 ( 45.8% of cap)  wall=01:47  rate= 25.5 t/s  speedup=1.27x  eta_to_cap=02:07     Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in  108.6s wall  frames= 554  sim_t= 138.5s  speedup= 1.28x  dist=  442.2m  risk_auc=800.200  finished=True
#
# Batch done in 2234.5s (ok=20, failed=0)

# %% [markdown]
# ## 5 — Summary

# %%
if not all_summaries and not failed:
    print("No trials were run.")
else:
    print(f"=== Successful runs ({len(all_summaries)}) ===")
    print(
        f"  {'trial_name':50s} {'frames':>6s} {'dist_m':>9s} "
        f"{'risk_auc':>9s} {'risk/m':>9s}  finished  run_path"
    )
    for s in all_summaries:
        print(
            f"  {s.trial_name:50s} {s.num_frames:6d} {s.traveled_m:9.1f} "
            f"{s.risk_auc:9.3f} {s.risk_per_meter:9.5f}  {str(s.finished):>8s}  {s.run_path}"
        )

    if failed:
        print()
        print(f"=== Failed runs ({len(failed)}) ===")
        for name, err in failed:
            print(f"  {name}: {err}")
# Out:
# === Successful runs (20) ===
#   trial_name                                         frames    dist_m  risk_auc    risk/m  finished  run_path
#   auto_17A_WetNoon_Town05_HighVol                       399     544.8   236.720   2.60762      True  t:\TFG\MIREIA\trials\auto_17A_WetNoon_Town05_HighVol\runs\20260512_192923_half_slow
#   auto_17B_WetNoon_Town05_LowVol                        152     561.7    68.831   2.00727      True  t:\TFG\MIREIA\trials\auto_17B_WetNoon_Town05_LowVol\runs\20260512_193046_half_slow
#   auto_17C_WetNoon_Town10HD_HighVol                     250     160.0   151.172   3.65554      True  t:\TFG\MIREIA\trials\auto_17C_WetNoon_Town10HD_HighVol\runs\20260512_193111_half_slow
#   auto_17D_WetNoon_Town10HD_LowVol                      644     423.0   365.009   3.55708      True  t:\TFG\MIREIA\trials\auto_17D_WetNoon_Town10HD_LowVol\runs\20260512_193209_half_slow
#   auto_18A_MidRainyNoon_Town05_HighVol                 1109     950.2  1292.148   6.15334      True  t:\TFG\MIREIA\trials\auto_18A_MidRainyNoon_Town05_HighVol\runs\20260512_193324_half_slow
#   auto_18B_MidRainyNoon_Town05_LowVol                   351     374.0   497.841   7.78764      True  t:\TFG\MIREIA\trials\auto_18B_MidRainyNoon_Town05_LowVol\runs\20260512_193656_half_slow
#   auto_18C_MidRainyNoon_Town10HD_HighVol               1200     120.9   767.846  11.26095     False  t:\TFG\MIREIA\trials\auto_18C_MidRainyNoon_Town10HD_HighVol\runs\20260512_193741_half_slow
#   auto_18D_MidRainyNoon_Town10HD_LowVol                 386     312.5   402.897   6.67226      True  t:\TFG\MIREIA\trials\auto_18D_MidRainyNoon_Town10HD_LowVol\runs\20260512_194147_half_slow
#   auto_19A_CloudySunset_Town05_HighVol                  199     152.9   116.709   3.32891      True  t:\TFG\MIREIA\trials\auto_19A_CloudySunset_Town05_HighVol\runs\20260512_194238_half_slow
#   auto_19B_CloudySunset_Town05_LowVol                   796     861.8   468.167   2.51321      True  t:\TFG\MIREIA\trials\auto_19B_CloudySunset_Town05_LowVol\runs\20260512_194326_half_slow
#   auto_19C_CloudySunset_Town10HD_HighVol               1200     654.4   787.867   4.48000     False  t:\TFG\MIREIA\trials\auto_19C_CloudySunset_Town10HD_HighVol\runs\20260512_194459_half_slow
#   auto_19D_CloudySunset_Town10HD_LowVol                 290     324.5   195.529   3.20225      True  t:\TFG\MIREIA\trials\auto_19D_CloudySunset_Town10HD_LowVol\runs\20260512_194912_half_slow
#   auto_20A_SoftRainSunset_Town05_HighVol                602     478.1   610.286   5.39179      True  t:\TFG\MIREIA\trials\auto_20A_SoftRainSunset_Town05_HighVol\runs\20260512_194954_half_slow
#   auto_20B_SoftRainSunset_Town05_LowVol                 963     997.7   609.162   2.75790      True  t:\TFG\MIREIA\trials\auto_20B_SoftRainSunset_Town05_LowVol\runs\20260512_195206_half_slow
#   auto_20C_SoftRainSunset_Town10HD_HighVol              594     719.9   636.836   4.94478      True  t:\TFG\MIREIA\trials\auto_20C_SoftRainSunset_Town10HD_HighVol\runs\20260512_195354_half_slow
#   auto_20D_SoftRainSunset_Town10HD_LowVol               650     669.1   460.822   3.71129      True  t:\TFG\MIREIA\trials\auto_20D_SoftRainSunset_Town10HD_LowVol\runs\20260512_195602_half_slow
#   auto_21A_ClearNoon_Town05_HighVol_NoFog_Night        1200    1096.7   662.621   2.32699     False  t:\TFG\MIREIA\trials\auto_21A_ClearNoon_Town05_HighVol_NoFog_Night\runs\20260512_195722_half_slow
#   auto_21B_CloudyNoon_Town05_LowVol_NoFog_Night         510     260.5   261.295   3.64256      True  t:\TFG\MIREIA\trials\auto_21B_CloudyNoon_Town05_LowVol_NoFog_Night\runs\20260512_200209_half_slow
#   auto_21C_WetNoon_Town10HD_HighVol_NoFog_Night         199     271.7   182.573   4.01352      True  t:\TFG\MIREIA\trials\auto_21C_WetNoon_Town10HD_HighVol_NoFog_Night\runs\20260512_200348_half_slow
#   auto_21D_HardRainNoon_Town10HD_LowVol_NoFog_Night     554     442.2   800.200   9.30179      True  t:\TFG\MIREIA\trials\auto_21D_HardRainNoon_Town10HD_LowVol_NoFog_Night\runs\20260512_200448_half_slow
