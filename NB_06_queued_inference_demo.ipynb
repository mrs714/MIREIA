# %% [markdown]
# # NB_06_queued_inference_demo - Queued Inference Demo - E2E vs Composed
#
# **Purpose.** Replay a recorded scenario through both models (E2E ResNet-18 -> BDU-GRU and Composed perception -> BDU-GRU) frame-by-frame and overlay their predictions on the ground-truth risk curve.
#
# **Inputs.** a dataset.jsonl under a scenario folder, plus the corresponding E2E and composed checkpoints.
#
# **Outputs.** per-frame predictions, MSE table, interactive matplotlib plot with model selector; Town05 / Town10 multi-scenario overlays.
#
# **How to run.** Set the scenario name and checkpoint paths in the Configuration section, then run top-to-bottom. The Town10 overlay loads composed checkpoints on demand.
#
# **Position in the workflow.** Offline counterpart to NB_07 (latency benchmark). Both follow NB_04 training.

# %%
import os
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
from ultralytics import YOLO

from MIREIA.config import Config
from MIREIA.data_collection.dataset_utils import load_jsonl_records, resolve_image_path
from MIREIA.perception import (
    DepthAnythingV2Estimator,
    FeatureIntegrator,
    QueuedComposedBDUGRURiskInference,
    QueuedE2ERiskInference,
    create_environment_classifier_predictor,
    load_road_segmentation_model,
)

# %% [markdown]
# ## Configuration

# %%
source_jsonl_name = "dataset.jsonl"
dataset_index = 72 #74          # Select dataset/scenario by index
start_frame = 0
num_frames_to_plot = 3500

# "e2e", "composed", or "both"
model_selection = "both"
selected_models = model_selection.strip().lower()
if selected_models not in {"e2e", "composed", "both"}:
    raise ValueError("model_selection must be one of: 'e2e', 'composed', 'both'")
run_e2e = selected_models in {"e2e", "both"}
run_composed = selected_models in {"composed", "both"}

# %% [markdown]
# ## Dataset Discovery + Frame Loading

# %%
from MIREIA.config import Config
from MIREIA.data_collection.dataset_utils import (
    load_jsonl_records,
    normalize_crop_bbox_xyxy,
    resolve_image_path,
)
from pathlib import Path

scenarios_root = Path(Config.PATH_TO_SCENARIOS)
scenario_dirs = [
    p for p in sorted(scenarios_root.iterdir())
    if p.is_dir() and p.name not in {"videos", "__pycache__"} and (p / source_jsonl_name).is_file()
]

if not scenario_dirs:
    raise RuntimeError(f"No scenarios with {source_jsonl_name} found under {scenarios_root}")

print("Available datasets (select by index):")
for i, d in enumerate(scenario_dirs):
    print(f"[{i:02d}] {d.name}")

if not (0 <= dataset_index < len(scenario_dirs)):
    raise ValueError(f"dataset_index={dataset_index} out of range [0, {len(scenario_dirs) - 1}]")

selected_scenario_dir = scenario_dirs[dataset_index]
records = load_jsonl_records(str(selected_scenario_dir / source_jsonl_name))
if not records:
    raise RuntimeError(f"No records found in {selected_scenario_dir / source_jsonl_name}")

end_frame = min(len(records), start_frame + int(num_frames_to_plot))
selected_records = records[start_frame:end_frame]

frame_paths, frame_ids, real_risks = [], [], []
for rec in selected_records:
    rel_image = str(rec.get("rgb_image_path", "")).strip()
    if not rel_image:
        continue
    full_path = resolve_image_path(str(selected_scenario_dir), rel_image, normalize_paths=True)
    if not os.path.isfile(full_path):
        continue
    frame_paths.append(full_path)
    frame_ids.append(int(rec.get("frame_id", len(frame_ids))))
    real_risks.append(float(rec.get("ground_truth_risk", 0.0)))

if not frame_paths:
    raise RuntimeError("No valid image paths found.")

# Composed-model features are computed on a dashboard-cropped image. Force the
# same fixed crop the trial batch runner (NB_13) uses, [0, 0, 512, 305], so this
# notebook's composed inference matches the trial pipeline exactly. (The labeled
# scenarios store a per-scenario crop_bbox_xyxy, but we deliberately override it
# here to keep NB_06 and NB_13 consistent.)
selected_crop_bbox_xyxy = [0, 0, 512, 305]

print(f"\nSelected: {selected_scenario_dir.name}")
print(f"Usable frames: {len(frame_paths)}  |  Model selection: {selected_models}")
print(f"Composed crop bbox (xyxy): {selected_crop_bbox_xyxy}")
# Out:
# Available datasets (select by index):
# [00] 01A_ClearNoon_Town01_HighVol
# [01] 01B_ClearNoon_Town01_LowVol
# [02] 01C_ClearNoon_Town02_HighVol
# [03] 01D_ClearNoon_Town02_LowVol
# [04] 02A_CloudyNoon_Town03_HighVol
# [05] 02B_CloudyNoon_Town03_LowVol
# [06] 02C_CloudyNoon_Town03_HighVol
# [07] 02D_CloudyNoon_Town04_LowVol
# [08] 03A_WetNoon_Town04_HighVol
# [09] 03B_WetNoon_Town04_LowVol
# [10] 03C_WetNoon_Town03_HighVol
# [11] 03D_WetNoon_Town04_LowVol
# [12] 04A_WetCloudyNoon_Town01_HighVol
# [13] 04B_WetCloudyNoon_Town01_LowVol
# [14] 04C_WetCloudyNoon_Town02_HighVol
# [15] 04D_WetCloudyNoon_Town02_LowVol
# [16] 05A_SoftRainNoon_Town03_HighVol
# [17] 05B_SoftRainNoon_Town03_LowVol
# [18] 05C_SoftRainNoon_Town01_HighVol
# [19] 05D_SoftRainNoon_Town02_LowVol
# [20] 06A_MidRainyNoon_Town04_HighVol
# [21] 06B_MidRainyNoon_Town04_LowVol
# [22] 06C_MidRainyNoon_Town03_HighVol
# [23] 06D_MidRainyNoon_Town04_LowVol
# [24] 07A_HardRainNoon_Town01_HighVol
# [25] 07B_HardRainNoon_Town01_LowVol
# [26] 07C_HardRainNoon_Town02_HighVol
# [27] 07D_HardRainNoon_Town02_LowVol
# [28] 08A_ClearSunset_Town03_HighVol
# [29] 08B_ClearSunset_Town03_LowVol
# [30] 08C_ClearSunset_Town01_HighVol
# [31] 08D_ClearSunset_Town02_LowVol
# [32] 09A_CloudySunset_Town04_HighVol
# [33] 09B_CloudySunset_Town04_LowVol
# [34] 09C_CloudySunset_Town03_HighVol
# [35] 09D_CloudySunset_Town04_LowVol
# [36] 10A_WetSunset_Town01_HighVol
# [37] 10B_WetSunset_Town01_LowVol
# [38] 10C_WetSunset_Town02_HighVol
# [39] 10D_WetSunset_Town02_LowVol
# [40] 11A_WetCloudySunset_Town03_HighVol
# [41] 11B_WetCloudySunset_Town03_LowVol
# [42] 11C_WetCloudySunset_Town01_HighVol
# [43] 11D_WetCloudySunset_Town02_LowVol
# [44] 12A_SoftRainSunset_Town04_HighVol
# [45] 12B_SoftRainSunset_Town04_LowVol
# [46] 12C_SoftRainSunset_Town03_HighVol
# [47] 12D_SoftRainSunset_Town04_LowVol
# [48] 13A_MidRainSunset_Town01_HighVol
# [49] 13B_MidRainSunset_Town01_LowVol
# [50] 13C_MidRainSunset_Town02_HighVol
# [51] 13D_MidRainSunset_Town02_LowVol
# [52] 14A_HardRainSunset_Town03_HighVol
# [53] 14B_HardRainSunset_Town03_LowVol
# [54] 14C_HardRainSunset_Town01_HighVol
# [55] 14D_HardRainSunset_Town02_LowVol
# [56] 15A_ClearNoon_Town04_HighVol_NoFog_Night
# [57] 15B_CloudyNoon_Town04_LowVol_NoFog_Night
# [58] 15C_WetNoon_Town03_HighVol_NoFog_Night
# [59] 15D_HardRainNoon_Town04_LowVol_NoFog_Night
# [60] 16A_ClearSunset_Town01_HighVol_Fog_Night
# [61] 16B_CloudySunset_Town01_LowVol_Fog_Night
# [62] 16C_SoftRainSunset_Town02_HighVol_Fog_Night
# [63] 16D_HardRainSunset_Town02_LowVol_Fog_Night
# [64] 17A_WetNoon_Town05_HighVol
# [65] 17B_WetNoon_Town05_LowVol
# [66] 17C_WetNoon_Town10HD_HighVol
# [67] 17D_WetNoon_Town10HD_LowVol
# [68] 18A_MidRainyNoon_Town05_HighVol
# [69] 18B_MidRainyNoon_Town05_LowVol
# [70] 18C_MidRainyNoon_Town10HD_HighVol
# [71] 18D_MidRainyNoon_Town10HD_LowVol
# [72] 19A_CloudySunset_Town05_HighVol
# [73] 19B_CloudySunset_Town05_LowVol
# [74] 19C_CloudySunset_Town10HD_HighVol
# [75] 19D_CloudySunset_Town10HD_LowVol
# [76] 20A_SoftRainSunset_Town05_HighVol
# [77] 20B_SoftRainSunset_Town05_LowVol
# [78] 20C_SoftRainSunset_Town10HD_HighVol
# [79] 20D_SoftRainSunset_Town10HD_LowVol
# [80] 21A_ClearNoon_Town05_HighVol_NoFog_Night
# [81] 21B_CloudyNoon_Town05_LowVol_NoFog_Night
# [82] 21C_WetNoon_Town10HD_HighVol_NoFog_Night
# [83] 21D_HardRainNoon_Town10HD_LowVol_NoFog_Night
#
# Selected: 19A_CloudySunset_Town05_HighVol
# Usable frames: 3500  |  Model selection: both
# Composed crop bbox (xyxy): [0, 0, 512, 305]

# %% [markdown]
# ## Model Loading
#
# ### Checkpoint Paths

# %%
device_name = "cuda" if torch.cuda.is_available() else "cpu"

MODEL_PATHS = {
    "yolo":     Path(Config.PATH_TO_MODELS) / "yolo11s.pt",
    "depth":    Path(Config.PATH_TO_MODELS) / "depth_anything_v2_vits.pth",
    "climate":  Path(Config.PATH_TO_MODELS) / "environment_multitask_checkpoint.pt",
    "road_seg": Path(Config.PATH_TO_MODELS) / "road_segmentation_multitask_checkpoint.pt",
}

e2e_checkpoint_paths = {
    #"e2e_latest": Path(Config.PATH_TO_MODELS) / "e2e_risk_checkpoint.pt",
    "e2e_1epoch": Path(Config.PATH_TO_MODELS) / "e2e_risk_checkpoint_1full_epoch.pt",
}

composed_checkpoint_paths = {
    "bdu_gru_search_02": Path(Config.PATH_TO_MODELS) / "bdu_gru_search_02.pt",  # no-skip model (matches NB_13)
}

other_bdu_gru = ["bdu_gru_run" + f"{i:02d}" for i in [2, 4]]
print("Names: " + ", ".join(other_bdu_gru))

composed_checkpoint_paths.update({name: Path(Config.PATH_TO_MODELS) / f"{name}.pt" for name in other_bdu_gru})
print("Composed checkpoint paths:")
for name, path in composed_checkpoint_paths.items():
    print(f"  {name}: {path}")

# Validation
required = {}
if run_e2e:
    required.update({f"e2e_{k}": v for k, v in e2e_checkpoint_paths.items()})
if run_composed:
    required.update({"yolo": MODEL_PATHS["yolo"], "depth": MODEL_PATHS["depth"]})
    required.update({f"{k}_ckpt": v for k, v in composed_checkpoint_paths.items()})

missing = [f"{k}: {v}" for k, v in required.items() if not Path(v).is_file()]
if missing:
    raise FileNotFoundError("Missing model files:\n" + "\n".join(missing))

print(f"Device: {device_name}")
# Out:
# Names: bdu_gru_run02, bdu_gru_run04
# Composed checkpoint paths:
#   bdu_gru_search_02: t:\TFG\MIREIA\models\bdu_gru_search_02.pt
#   bdu_gru_run02: t:\TFG\MIREIA\models\bdu_gru_run02.pt
#   bdu_gru_run04: t:\TFG\MIREIA\models\bdu_gru_run04.pt
# Device: cuda

# %% [markdown]
# ### Load E2E Predictors

# %%
e2e_predictors = {}
if run_e2e:
    for name, ckpt_path in e2e_checkpoint_paths.items():
        e2e_predictors[name] = QueuedE2ERiskInference.from_checkpoint(
            checkpoint_path=str(ckpt_path),
            device=device_name,
        )
        print(f"Loaded E2E: {name}")

e2e_predictor = next(iter(e2e_predictors.values())) if e2e_predictors else None
# Out:
# Loaded E2E: e2e_1epoch

# %% [markdown]
# ### Load Composed Predictors

# %%
composed_predictors = {}
yolo_model = depth_estimator = environment_predictor = road_segmentation = None

if run_composed:
    yolo_model = YOLO(str(MODEL_PATHS["yolo"]))
    depth_estimator = DepthAnythingV2Estimator(
        checkpoint_path=MODEL_PATHS["depth"],
        encoder="vits",
        device=device_name,
    )
    environment_predictor = (
        create_environment_classifier_predictor(
            checkpoint_path=str(MODEL_PATHS["climate"]), device=device_name
        ) if MODEL_PATHS["climate"].is_file() else None
    )
    road_segmentation = (
        load_road_segmentation_model(checkpoint_path=str(MODEL_PATHS["road_seg"]), device=device_name)
        if MODEL_PATHS["road_seg"].is_file() else None
    )

    for name, checkpoint_path in composed_checkpoint_paths.items():
        composed_predictors[name] = QueuedComposedBDUGRURiskInference.from_checkpoint(
            checkpoint_path=str(checkpoint_path),
            feature_integrator=FeatureIntegrator(),
            yolo_model=yolo_model,
            depth_estimator=depth_estimator,
            environment_predictor=environment_predictor,
            road_segmentation=road_segmentation,
            device=device_name,
            manual_crop_bbox=selected_crop_bbox_xyxy,  # match the dashboard crop used at labeling
        )
        print(f"Loaded Composed: {name}")

print("Environment predictor loaded:", environment_predictor is not None)
print("Road segmentation loaded:", road_segmentation is not None)
# Out:
# Loaded Composed: bdu_gru_search_02
# Loaded Composed: bdu_gru_run02
# Loaded Composed: bdu_gru_run04
# Environment predictor loaded: True
# Road segmentation loaded: True

# %% [markdown]
# ## Inference
#
# ### Helper

# %%
from time import perf_counter

used_frame_ids = [int(fid) for fid in frame_ids]
real_vals = [float(r) for r in real_risks]
total_frames = len(frame_paths)


def _run_model_inference(model_name, predictor):
    predictor.reset_queue()
    preds = []
    t_start = perf_counter()

    for done, (frame_path, frame_id) in enumerate(zip(frame_paths, used_frame_ids), start=1):
        out = predictor.add_image_path(frame_path)
        preds.append(float(out.latest_risk) if out.ready and out.latest_risk is not None else np.nan)

        if done % 10 == 0 or done == total_frames:
            elapsed_s = perf_counter() - t_start
            fps = done / max(elapsed_s, 1e-9)
            eta_s = (total_frames - done) / max(fps, 1e-9)
            print(f"[{model_name}] [{done}/{total_frames}] fps={fps:.1f} eta={eta_s:.1f}s")

    elapsed_total = perf_counter() - t_start
    fps_total = total_frames / max(elapsed_total, 1e-9)
    print(f"[{model_name}] done in {elapsed_total:.1f}s ({fps_total:.1f} FPS).")
    return preds, elapsed_total, fps_total

# %% [markdown]
# ### Run E2E

# %%
e2e_preds_by_model, e2e_elapsed_by_model, e2e_fps_by_model = {}, {}, {}

if run_e2e:
    print("Running E2E inference...")
    for ckpt_name, predictor in e2e_predictors.items():
        preds, elapsed_s, fps = _run_model_inference(f"E2E:{ckpt_name}", predictor)
        e2e_preds_by_model[ckpt_name] = preds
        e2e_elapsed_by_model[ckpt_name] = elapsed_s
        e2e_fps_by_model[ckpt_name] = fps

# Backward-compat alias
_e2e_default_key = next(iter(e2e_preds_by_model)) if e2e_preds_by_model else None
e2e_preds = e2e_preds_by_model[_e2e_default_key] if _e2e_default_key else [np.nan] * total_frames
e2e_fps = e2e_fps_by_model[_e2e_default_key] if _e2e_default_key else float("nan")
# Out:
# Running E2E inference...
# [E2E:e2e_1epoch] [10/3500] fps=37.9 eta=92.1s
# [E2E:e2e_1epoch] [20/3500] fps=36.8 eta=94.7s
# [E2E:e2e_1epoch] [30/3500] fps=35.5 eta=97.6s
# [E2E:e2e_1epoch] [40/3500] fps=35.0 eta=98.8s
# [E2E:e2e_1epoch] [50/3500] fps=34.6 eta=99.6s
# [E2E:e2e_1epoch] [60/3500] fps=34.5 eta=99.7s
# [E2E:e2e_1epoch] [70/3500] fps=34.5 eta=99.5s
# [E2E:e2e_1epoch] [80/3500] fps=34.4 eta=99.3s
# [E2E:e2e_1epoch] [90/3500] fps=34.5 eta=98.8s
# [E2E:e2e_1epoch] [100/3500] fps=34.6 eta=98.2s
# [E2E:e2e_1epoch] [110/3500] fps=34.6 eta=97.9s
# [E2E:e2e_1epoch] [120/3500] fps=34.7 eta=97.5s
# [E2E:e2e_1epoch] [130/3500] fps=34.7 eta=97.2s
# [E2E:e2e_1epoch] [140/3500] fps=34.7 eta=96.8s
# [E2E:e2e_1epoch] [150/3500] fps=34.7 eta=96.5s
# [E2E:e2e_1epoch] [160/3500] fps=34.7 eta=96.2s
# [E2E:e2e_1epoch] [170/3500] fps=34.8 eta=95.6s
# [E2E:e2e_1epoch] [180/3500] fps=34.4 eta=96.6s
# [E2E:e2e_1epoch] [190/3500] fps=34.4 eta=96.2s
# [E2E:e2e_1epoch] [200/3500] fps=34.5 eta=95.7s
# [E2E:e2e_1epoch] [210/3500] fps=34.6 eta=95.1s
# [E2E:e2e_1epoch] [220/3500] fps=34.7 eta=94.6s
# [E2E:e2e_1epoch] [230/3500] fps=34.7 eta=94.2s
# [E2E:e2e_1epoch] [240/3500] fps=34.8 eta=93.7s
# [E2E:e2e_1epoch] [250/3500] fps=34.8 eta=93.3s
# [E2E:e2e_1epoch] [260/3500] fps=34.9 eta=92.7s
# [E2E:e2e_1epoch] [270/3500] fps=35.0 eta=92.2s
# [E2E:e2e_1epoch] [280/3500] fps=35.1 eta=91.7s
# [E2E:e2e_1epoch] [290/3500] fps=35.2 eta=91.2s
# [E2E:e2e_1epoch] [300/3500] fps=35.3 eta=90.8s
# [E2E:e2e_1epoch] [310/3500] fps=35.3 eta=90.4s
# [E2E:e2e_1epoch] [320/3500] fps=35.3 eta=90.0s
# [E2E:e2e_1epoch] [330/3500] fps=35.4 eta=89.7s
# [E2E:e2e_1epoch] [340/3500] fps=35.4 eta=89.2s
# [E2E:e2e_1epoch] [350/3500] fps=35.5 eta=88.8s
# [E2E:e2e_1epoch] [360/3500] fps=35.6 eta=88.3s
# [E2E:e2e_1epoch] [370/3500] fps=35.6 eta=88.0s
# [E2E:e2e_1epoch] [380/3500] fps=35.6 eta=87.6s
# [E2E:e2e_1epoch] [390/3500] fps=35.7 eta=87.2s
# [E2E:e2e_1epoch] [400/3500] fps=35.7 eta=86.8s
# [E2E:e2e_1epoch] [410/3500] fps=35.8 eta=86.3s
# [E2E:e2e_1epoch] [420/3500] fps=35.9 eta=85.9s
# [E2E:e2e_1epoch] [430/3500] fps=35.9 eta=85.5s
# [E2E:e2e_1epoch] [440/3500] fps=36.0 eta=85.1s
# [E2E:e2e_1epoch] [450/3500] fps=36.0 eta=84.7s
# [E2E:e2e_1epoch] [460/3500] fps=36.0 eta=84.4s
# [E2E:e2e_1epoch] [470/3500] fps=36.1 eta=84.0s
# [E2E:e2e_1epoch] [480/3500] fps=36.1 eta=83.6s
# [E2E:e2e_1epoch] [490/3500] fps=36.1 eta=83.3s
# [E2E:e2e_1epoch] [500/3500] fps=36.2 eta=82.9s
# [E2E:e2e_1epoch] [510/3500] fps=36.2 eta=82.5s
# [E2E:e2e_1epoch] [520/3500] fps=36.3 eta=82.2s
# [E2E:e2e_1epoch] [530/3500] fps=36.3 eta=81.8s
# [E2E:e2e_1epoch] [540/3500] fps=36.3 eta=81.5s
# [E2E:e2e_1epoch] [550/3500] fps=36.4 eta=81.1s
# [E2E:e2e_1epoch] [560/3500] fps=36.4 eta=80.8s
# [E2E:e2e_1epoch] [570/3500] fps=36.4 eta=80.5s
# [E2E:e2e_1epoch] [580/3500] fps=36.4 eta=80.1s
# [E2E:e2e_1epoch] [590/3500] fps=36.5 eta=79.8s
# [E2E:e2e_1epoch] [600/3500] fps=36.5 eta=79.5s
# [E2E:e2e_1epoch] [610/3500] fps=36.5 eta=79.2s
# [E2E:e2e_1epoch] [620/3500] fps=36.5 eta=78.9s
# [E2E:e2e_1epoch] [630/3500] fps=36.5 eta=78.6s
# [E2E:e2e_1epoch] [640/3500] fps=36.6 eta=78.2s
# [E2E:e2e_1epoch] [650/3500] fps=36.6 eta=77.9s
# [E2E:e2e_1epoch] [660/3500] fps=36.6 eta=77.6s
# [E2E:e2e_1epoch] [1100/3500] fps=37.0 eta=64.9s
# [E2E:e2e_1epoch] [1110/3500] fps=37.0 eta=64.6s
# [E2E:e2e_1epoch] [1120/3500] fps=37.0 eta=64.3s
# [E2E:e2e_1epoch] [1130/3500] fps=37.0 eta=64.0s
# [E2E:e2e_1epoch] [1140/3500] fps=37.0 eta=63.8s
# [E2E:e2e_1epoch] [1150/3500] fps=37.0 eta=63.5s
# [E2E:e2e_1epoch] [1160/3500] fps=37.0 eta=63.2s
# [E2E:e2e_1epoch] [1170/3500] fps=37.0 eta=62.9s
# [E2E:e2e_1epoch] [1180/3500] fps=37.0 eta=62.6s
# [E2E:e2e_1epoch] [1190/3500] fps=37.0 eta=62.4s
# [E2E:e2e_1epoch] [1200/3500] fps=37.0 eta=62.1s
# [E2E:e2e_1epoch] [1210/3500] fps=37.0 eta=61.8s
# [E2E:e2e_1epoch] [1220/3500] fps=37.0 eta=61.6s
# [E2E:e2e_1epoch] [1230/3500] fps=37.0 eta=61.3s
# [E2E:e2e_1epoch] [1240/3500] fps=37.0 eta=61.0s
# [E2E:e2e_1epoch] [1250/3500] fps=37.0 eta=60.8s
# [E2E:e2e_1epoch] [1260/3500] fps=37.0 eta=60.5s
# [E2E:e2e_1epoch] [1270/3500] fps=37.0 eta=60.2s
# [E2E:e2e_1epoch] [1280/3500] fps=37.1 eta=59.9s
# [E2E:e2e_1epoch] [1290/3500] fps=37.1 eta=59.6s
# [E2E:e2e_1epoch] [1300/3500] fps=37.1 eta=59.4s
# [E2E:e2e_1epoch] [1310/3500] fps=37.1 eta=59.1s
# [E2E:e2e_1epoch] [1320/3500] fps=37.1 eta=58.8s
# [E2E:e2e_1epoch] [1330/3500] fps=37.1 eta=58.6s
# [E2E:e2e_1epoch] [1340/3500] fps=37.1 eta=58.3s
# [E2E:e2e_1epoch] [1350/3500] fps=37.1 eta=58.0s
# [E2E:e2e_1epoch] [1360/3500] fps=37.1 eta=57.7s
# [E2E:e2e_1epoch] [1370/3500] fps=37.1 eta=57.5s
# [E2E:e2e_1epoch] [1380/3500] fps=37.1 eta=57.2s
# [E2E:e2e_1epoch] [1390/3500] fps=37.1 eta=56.9s
# [E2E:e2e_1epoch] [1400/3500] fps=37.1 eta=56.6s
# [E2E:e2e_1epoch] [1410/3500] fps=37.1 eta=56.4s
# [E2E:e2e_1epoch] [1420/3500] fps=37.1 eta=56.1s
# [E2E:e2e_1epoch] [1430/3500] fps=37.1 eta=55.8s
# [E2E:e2e_1epoch] [1440/3500] fps=37.1 eta=55.6s
# [E2E:e2e_1epoch] [1450/3500] fps=37.1 eta=55.3s
# [E2E:e2e_1epoch] [1460/3500] fps=37.1 eta=55.0s
# [E2E:e2e_1epoch] [1470/3500] fps=37.1 eta=54.8s
# [E2E:e2e_1epoch] [1480/3500] fps=37.1 eta=54.5s
# [E2E:e2e_1epoch] [1490/3500] fps=37.1 eta=54.2s
# [E2E:e2e_1epoch] [1500/3500] fps=37.0 eta=54.0s
# [E2E:e2e_1epoch] [1510/3500] fps=37.0 eta=53.7s
# [E2E:e2e_1epoch] [1520/3500] fps=37.0 eta=53.5s
# [E2E:e2e_1epoch] [1530/3500] fps=37.0 eta=53.2s
# [E2E:e2e_1epoch] [1540/3500] fps=37.0 eta=53.0s
# [E2E:e2e_1epoch] [1550/3500] fps=37.0 eta=52.7s
# [E2E:e2e_1epoch] [1560/3500] fps=37.0 eta=52.4s
# [E2E:e2e_1epoch] [1570/3500] fps=37.0 eta=52.2s
# [E2E:e2e_1epoch] [1580/3500] fps=37.0 eta=51.9s
# [E2E:e2e_1epoch] [1590/3500] fps=37.0 eta=51.7s
# [E2E:e2e_1epoch] [1600/3500] fps=37.0 eta=51.4s
# [E2E:e2e_1epoch] [1610/3500] fps=36.9 eta=51.2s
# [E2E:e2e_1epoch] [1620/3500] fps=36.9 eta=50.9s
# [E2E:e2e_1epoch] [1630/3500] fps=36.9 eta=50.7s
# [E2E:e2e_1epoch] [1640/3500] fps=36.9 eta=50.4s
# [E2E:e2e_1epoch] [1650/3500] fps=36.9 eta=50.1s
# [E2E:e2e_1epoch] [1660/3500] fps=36.9 eta=49.9s
# [E2E:e2e_1epoch] [1670/3500] fps=36.9 eta=49.6s
# [E2E:e2e_1epoch] [1680/3500] fps=36.8 eta=49.4s
# [E2E:e2e_1epoch] [1690/3500] fps=36.8 eta=49.1s
# [E2E:e2e_1epoch] [1700/3500] fps=36.8 eta=48.9s
# [E2E:e2e_1epoch] [1710/3500] fps=36.8 eta=48.7s
# [E2E:e2e_1epoch] [1720/3500] fps=36.8 eta=48.4s
# [E2E:e2e_1epoch] [1730/3500] fps=36.8 eta=48.1s
# [E2E:e2e_1epoch] [1740/3500] fps=36.7 eta=47.9s
# [E2E:e2e_1epoch] [1750/3500] fps=36.7 eta=47.6s
# [E2E:e2e_1epoch] [1760/3500] fps=36.7 eta=47.4s
# [E2E:e2e_1epoch] [1770/3500] fps=36.7 eta=47.1s
# [E2E:e2e_1epoch] [1780/3500] fps=36.7 eta=46.9s
# [E2E:e2e_1epoch] [1790/3500] fps=36.7 eta=46.6s
# [E2E:e2e_1epoch] [1800/3500] fps=36.7 eta=46.4s
# [E2E:e2e_1epoch] [1810/3500] fps=36.7 eta=46.1s
# [E2E:e2e_1epoch] [1820/3500] fps=36.6 eta=45.8s
# [E2E:e2e_1epoch] [1830/3500] fps=36.6 eta=45.6s
# [E2E:e2e_1epoch] [1840/3500] fps=36.6 eta=45.3s
# [E2E:e2e_1epoch] [1850/3500] fps=36.6 eta=45.1s
# [E2E:e2e_1epoch] [1860/3500] fps=36.6 eta=44.8s
# [E2E:e2e_1epoch] [1870/3500] fps=36.6 eta=44.6s
# [E2E:e2e_1epoch] [1880/3500] fps=36.6 eta=44.3s
# [E2E:e2e_1epoch] [1890/3500] fps=36.6 eta=44.0s
# [E2E:e2e_1epoch] [1900/3500] fps=36.6 eta=43.8s
# [E2E:e2e_1epoch] [1910/3500] fps=36.5 eta=43.5s
# [E2E:e2e_1epoch] [1920/3500] fps=36.5 eta=43.2s
# [E2E:e2e_1epoch] [1930/3500] fps=36.5 eta=43.0s
# [E2E:e2e_1epoch] [2360/3500] fps=36.3 eta=31.4s
# [E2E:e2e_1epoch] [2370/3500] fps=36.3 eta=31.1s
# [E2E:e2e_1epoch] [2380/3500] fps=36.3 eta=30.8s
# [E2E:e2e_1epoch] [2390/3500] fps=36.3 eta=30.6s
# [E2E:e2e_1epoch] [2400/3500] fps=36.3 eta=30.3s
# [E2E:e2e_1epoch] [2410/3500] fps=36.3 eta=30.0s
# [E2E:e2e_1epoch] [2420/3500] fps=36.3 eta=29.7s
# [E2E:e2e_1epoch] [2430/3500] fps=36.3 eta=29.5s
# [E2E:e2e_1epoch] [2440/3500] fps=36.3 eta=29.2s
# [E2E:e2e_1epoch] [2450/3500] fps=36.3 eta=28.9s
# [E2E:e2e_1epoch] [2460/3500] fps=36.3 eta=28.6s
# [E2E:e2e_1epoch] [2470/3500] fps=36.3 eta=28.4s
# [E2E:e2e_1epoch] [2480/3500] fps=36.3 eta=28.1s
# [E2E:e2e_1epoch] [2490/3500] fps=36.3 eta=27.8s
# [E2E:e2e_1epoch] [2500/3500] fps=36.3 eta=27.5s
# [E2E:e2e_1epoch] [2510/3500] fps=36.4 eta=27.2s
# [E2E:e2e_1epoch] [2520/3500] fps=36.4 eta=26.9s
# [E2E:e2e_1epoch] [2530/3500] fps=36.4 eta=26.7s
# [E2E:e2e_1epoch] [2540/3500] fps=36.4 eta=26.4s
# [E2E:e2e_1epoch] [2550/3500] fps=36.4 eta=26.1s
# [E2E:e2e_1epoch] [2560/3500] fps=36.4 eta=25.8s
# [E2E:e2e_1epoch] [2570/3500] fps=36.4 eta=25.5s
# [E2E:e2e_1epoch] [2580/3500] fps=36.4 eta=25.3s
# [E2E:e2e_1epoch] [2590/3500] fps=36.4 eta=25.0s
# [E2E:e2e_1epoch] [2600/3500] fps=36.4 eta=24.7s
# [E2E:e2e_1epoch] [2610/3500] fps=36.4 eta=24.4s
# [E2E:e2e_1epoch] [2620/3500] fps=36.5 eta=24.1s
# [E2E:e2e_1epoch] [2630/3500] fps=36.5 eta=23.9s
# [E2E:e2e_1epoch] [2640/3500] fps=36.5 eta=23.6s
# [E2E:e2e_1epoch] [2650/3500] fps=36.5 eta=23.3s
# [E2E:e2e_1epoch] [2660/3500] fps=36.5 eta=23.0s
# [E2E:e2e_1epoch] [2670/3500] fps=36.5 eta=22.7s
# [E2E:e2e_1epoch] [2680/3500] fps=36.5 eta=22.5s
# [E2E:e2e_1epoch] [2690/3500] fps=36.5 eta=22.2s
# [E2E:e2e_1epoch] [2700/3500] fps=36.5 eta=21.9s
# [E2E:e2e_1epoch] [2710/3500] fps=36.5 eta=21.6s
# [E2E:e2e_1epoch] [2720/3500] fps=36.5 eta=21.4s
# [E2E:e2e_1epoch] [2730/3500] fps=36.5 eta=21.1s
# [E2E:e2e_1epoch] [2740/3500] fps=36.5 eta=20.8s
# [E2E:e2e_1epoch] [2750/3500] fps=36.5 eta=20.5s
# [E2E:e2e_1epoch] [2760/3500] fps=36.5 eta=20.3s
# [E2E:e2e_1epoch] [2770/3500] fps=36.5 eta=20.0s
# [E2E:e2e_1epoch] [3200/3500] fps=36.6 eta=8.2s
# [E2E:e2e_1epoch] [3210/3500] fps=36.7 eta=7.9s
# [E2E:e2e_1epoch] [3220/3500] fps=36.7 eta=7.6s
# [E2E:e2e_1epoch] [3230/3500] fps=36.7 eta=7.4s
# [E2E:e2e_1epoch] [3240/3500] fps=36.7 eta=7.1s
# [E2E:e2e_1epoch] [3250/3500] fps=36.7 eta=6.8s
# [E2E:e2e_1epoch] [3260/3500] fps=36.7 eta=6.5s
# [E2E:e2e_1epoch] [3270/3500] fps=36.7 eta=6.3s
# [E2E:e2e_1epoch] [3280/3500] fps=36.7 eta=6.0s
# [E2E:e2e_1epoch] [3290/3500] fps=36.7 eta=5.7s
# [E2E:e2e_1epoch] [3300/3500] fps=36.7 eta=5.4s
# [E2E:e2e_1epoch] [3310/3500] fps=36.7 eta=5.2s
# [E2E:e2e_1epoch] [3320/3500] fps=36.7 eta=4.9s
# [E2E:e2e_1epoch] [3330/3500] fps=36.7 eta=4.6s
# [E2E:e2e_1epoch] [3340/3500] fps=36.7 eta=4.4s
# [E2E:e2e_1epoch] [3350/3500] fps=36.7 eta=4.1s
# [E2E:e2e_1epoch] [3360/3500] fps=36.7 eta=3.8s
# [E2E:e2e_1epoch] [3370/3500] fps=36.7 eta=3.5s
# [E2E:e2e_1epoch] [3380/3500] fps=36.7 eta=3.3s
# [E2E:e2e_1epoch] [3390/3500] fps=36.7 eta=3.0s
# [E2E:e2e_1epoch] [3400/3500] fps=36.7 eta=2.7s
# [E2E:e2e_1epoch] [3410/3500] fps=36.7 eta=2.5s
# [E2E:e2e_1epoch] [3420/3500] fps=36.7 eta=2.2s
# [E2E:e2e_1epoch] [3430/3500] fps=36.7 eta=1.9s
# [E2E:e2e_1epoch] [3440/3500] fps=36.7 eta=1.6s
# [E2E:e2e_1epoch] [3450/3500] fps=36.7 eta=1.4s
# [E2E:e2e_1epoch] [3460/3500] fps=36.7 eta=1.1s
# [E2E:e2e_1epoch] [3470/3500] fps=36.7 eta=0.8s
# [E2E:e2e_1epoch] [3480/3500] fps=36.7 eta=0.5s
# [E2E:e2e_1epoch] [3490/3500] fps=36.7 eta=0.3s
# [E2E:e2e_1epoch] [3500/3500] fps=36.7 eta=0.0s
# [E2E:e2e_1epoch] done in 95.3s (36.7 FPS).

# %% [markdown]
# ### Run Composed BDU-GRU

# %%
composed_preds_by_model, composed_elapsed_by_model, composed_fps_by_model = {}, {}, {}

if run_composed:
    print("Running Composed BDU-GRU inference...")
    for ckpt_name, predictor in composed_predictors.items():
        preds, elapsed_s, fps = _run_model_inference(f"Composed:{ckpt_name}", predictor)
        composed_preds_by_model[ckpt_name] = preds
        composed_elapsed_by_model[ckpt_name] = elapsed_s
        composed_fps_by_model[ckpt_name] = fps

# Backward-compat alias
default_composed_key = next(iter(composed_preds_by_model)) if composed_preds_by_model else None
composed_preds = composed_preds_by_model[default_composed_key] if default_composed_key else [np.nan] * total_frames
composed_fps = composed_fps_by_model[default_composed_key] if default_composed_key else float("nan")

print("\nFPS summary:")
for k, v in {**e2e_fps_by_model, **composed_fps_by_model}.items():
    print(f"  {k}: {v:.1f} FPS")
# Out:
# Running Composed BDU-GRU inference...
# [Composed:bdu_gru_search_02] [10/3500] fps=7.2 eta=482.7s
# [Composed:bdu_gru_search_02] [20/3500] fps=8.0 eta=434.1s
# [Composed:bdu_gru_search_02] [30/3500] fps=8.2 eta=425.3s
# [Composed:bdu_gru_search_02] [40/3500] fps=8.3 eta=416.4s
# [Composed:bdu_gru_search_02] [50/3500] fps=8.5 eta=406.1s
# [Composed:bdu_gru_search_02] [60/3500] fps=8.6 eta=399.8s
# [Composed:bdu_gru_search_02] [70/3500] fps=8.7 eta=395.0s
# [Composed:bdu_gru_search_02] [80/3500] fps=8.7 eta=392.1s
# [Composed:bdu_gru_search_02] [90/3500] fps=8.7 eta=390.3s
# [Composed:bdu_gru_search_02] [100/3500] fps=8.8 eta=387.7s
# [Composed:bdu_gru_search_02] [110/3500] fps=8.8 eta=384.8s
# [Composed:bdu_gru_search_02] [120/3500] fps=8.8 eta=382.4s
# [Composed:bdu_gru_search_02] [130/3500] fps=8.9 eta=380.4s
# [Composed:bdu_gru_search_02] [140/3500] fps=8.9 eta=377.1s
# [Composed:bdu_gru_search_02] [150/3500] fps=8.9 eta=374.6s
# [Composed:bdu_gru_search_02] [160/3500] fps=9.0 eta=372.7s
# [Composed:bdu_gru_search_02] [170/3500] fps=9.0 eta=371.8s
# [Composed:bdu_gru_search_02] [180/3500] fps=9.0 eta=370.0s
# [Composed:bdu_gru_search_02] [190/3500] fps=9.0 eta=368.2s
# [Composed:bdu_gru_search_02] [200/3500] fps=9.0 eta=365.9s
# [Composed:bdu_gru_search_02] [210/3500] fps=9.0 eta=364.3s
# [Composed:bdu_gru_search_02] [220/3500] fps=9.0 eta=363.5s
# [Composed:bdu_gru_search_02] [230/3500] fps=9.0 eta=361.7s
# [Composed:bdu_gru_search_02] [240/3500] fps=9.1 eta=360.1s
# [Composed:bdu_gru_search_02] [250/3500] fps=9.1 eta=358.4s
# [Composed:bdu_gru_search_02] [260/3500] fps=9.1 eta=357.1s
# [Composed:bdu_gru_search_02] [270/3500] fps=9.0 eta=357.0s
# [Composed:bdu_gru_search_02] [280/3500] fps=9.0 eta=356.2s
# [Composed:bdu_gru_search_02] [290/3500] fps=9.0 eta=355.0s
# [Composed:bdu_gru_search_02] [300/3500] fps=9.0 eta=354.2s
# [Composed:bdu_gru_search_02] [310/3500] fps=9.0 eta=353.1s
# [Composed:bdu_gru_search_02] [320/3500] fps=9.0 eta=352.2s
# [Composed:bdu_gru_search_02] [330/3500] fps=9.0 eta=351.5s
# [Composed:bdu_gru_search_02] [340/3500] fps=9.0 eta=350.5s
# [Composed:bdu_gru_search_02] [350/3500] fps=9.0 eta=349.6s
# [Composed:bdu_gru_search_02] [360/3500] fps=9.0 eta=349.1s
# [Composed:bdu_gru_search_02] [370/3500] fps=9.0 eta=348.5s
# [Composed:bdu_gru_search_02] [380/3500] fps=9.0 eta=347.9s
# [Composed:bdu_gru_search_02] [390/3500] fps=9.0 eta=347.1s
# [Composed:bdu_gru_run02] [3380/3500] fps=8.9 eta=13.5s
# [Composed:bdu_gru_run02] [3390/3500] fps=8.9 eta=12.3s
# [Composed:bdu_gru_run02] [3400/3500] fps=8.9 eta=11.2s
# [Composed:bdu_gru_run02] [3410/3500] fps=8.9 eta=10.1s
# [Composed:bdu_gru_run02] [3420/3500] fps=8.9 eta=9.0s
# [Composed:bdu_gru_run02] [3430/3500] fps=8.9 eta=7.9s
# [Composed:bdu_gru_run02] [3440/3500] fps=8.9 eta=6.7s
# [Composed:bdu_gru_run02] [3450/3500] fps=8.9 eta=5.6s
# [Composed:bdu_gru_run02] [3460/3500] fps=8.9 eta=4.5s
# [Composed:bdu_gru_run02] [3470/3500] fps=8.9 eta=3.4s
# [Composed:bdu_gru_run02] [3480/3500] fps=8.9 eta=2.2s
# [Composed:bdu_gru_run02] [3490/3500] fps=8.9 eta=1.1s
# [Composed:bdu_gru_run02] [3500/3500] fps=8.9 eta=0.0s
# [Composed:bdu_gru_run02] done in 392.7s (8.9 FPS).
# [Composed:bdu_gru_run04] [10/3500] fps=9.4 eta=371.1s
# [Composed:bdu_gru_run04] [20/3500] fps=9.4 eta=369.6s
# [Composed:bdu_gru_run04] [30/3500] fps=9.2 eta=375.2s
# [Composed:bdu_gru_run04] [40/3500] fps=9.2 eta=376.9s
# [Composed:bdu_gru_run04] [50/3500] fps=9.1 eta=379.0s
# [Composed:bdu_gru_run04] [60/3500] fps=9.1 eta=378.3s
# [Composed:bdu_gru_run04] [70/3500] fps=9.1 eta=378.1s
# [Composed:bdu_gru_run04] [80/3500] fps=9.1 eta=376.5s
# [Composed:bdu_gru_run04] [90/3500] fps=9.0 eta=377.1s
# [Composed:bdu_gru_run04] [100/3500] fps=9.0 eta=377.0s
# [Composed:bdu_gru_run04] [110/3500] fps=9.0 eta=376.4s
# [Composed:bdu_gru_run04] [120/3500] fps=9.0 eta=376.8s
# [Composed:bdu_gru_run04] [130/3500] fps=9.0 eta=376.5s
# [Composed:bdu_gru_run04] [140/3500] fps=8.9 eta=375.5s
# [Composed:bdu_gru_run04] [150/3500] fps=9.0 eta=373.2s
# [Composed:bdu_gru_run04] [160/3500] fps=9.0 eta=371.9s
# [Composed:bdu_gru_run04] [170/3500] fps=9.0 eta=370.5s
# [Composed:bdu_gru_run04] [180/3500] fps=9.0 eta=369.7s
# [Composed:bdu_gru_run04] [190/3500] fps=9.0 eta=367.7s
# [Composed:bdu_gru_run04] [200/3500] fps=9.0 eta=366.3s
# [Composed:bdu_gru_run04] [210/3500] fps=9.0 eta=365.8s
# [Composed:bdu_gru_run04] [220/3500] fps=9.0 eta=365.5s
# [Composed:bdu_gru_run04] [230/3500] fps=9.0 eta=364.3s
# [Composed:bdu_gru_run04] [240/3500] fps=9.0 eta=363.1s
# [Composed:bdu_gru_run04] [250/3500] fps=9.0 eta=361.9s
# [Composed:bdu_gru_run04] [260/3500] fps=9.0 eta=360.7s
# [Composed:bdu_gru_run04] [270/3500] fps=9.0 eta=359.6s
# [Composed:bdu_gru_run04] [280/3500] fps=9.0 eta=359.3s
# [Composed:bdu_gru_run04] [290/3500] fps=9.0 eta=357.6s
# [Composed:bdu_gru_run04] [300/3500] fps=9.0 eta=357.0s
# [Composed:bdu_gru_run04] [310/3500] fps=8.9 eta=356.5s
# [Composed:bdu_gru_run04] [320/3500] fps=8.9 eta=355.9s
# [Composed:bdu_gru_run04] [330/3500] fps=8.9 eta=354.8s
# [Composed:bdu_gru_run04] [340/3500] fps=8.9 eta=355.4s
# [Composed:bdu_gru_run04] [350/3500] fps=8.9 eta=355.3s
# [Composed:bdu_gru_run04] [360/3500] fps=8.8 eta=355.0s
# [Composed:bdu_gru_run04] [370/3500] fps=8.9 eta=353.6s
# [Composed:bdu_gru_run04] [380/3500] fps=8.8 eta=352.8s
# [Composed:bdu_gru_run04] [390/3500] fps=8.9 eta=351.4s
# [Composed:bdu_gru_run04] [400/3500] fps=8.9 eta=350.1s
# [Composed:bdu_gru_run04] [410/3500] fps=8.9 eta=348.8s
# [Composed:bdu_gru_run04] [420/3500] fps=8.9 eta=347.6s
# [Composed:bdu_gru_run04] [430/3500] fps=8.9 eta=346.2s
# [Composed:bdu_gru_run04] [440/3500] fps=8.9 eta=344.7s
# [Composed:bdu_gru_run04] [450/3500] fps=8.9 eta=343.6s
# [Composed:bdu_gru_run04] [460/3500] fps=8.9 eta=342.6s
# [Composed:bdu_gru_run04] [470/3500] fps=8.9 eta=340.8s
# [Composed:bdu_gru_run04] [480/3500] fps=8.9 eta=339.2s
# [Composed:bdu_gru_run04] [490/3500] fps=8.9 eta=337.5s
# [Composed:bdu_gru_run04] [500/3500] fps=8.9 eta=336.0s
# [Composed:bdu_gru_run04] [510/3500] fps=8.9 eta=334.8s
# [Composed:bdu_gru_run04] [520/3500] fps=8.9 eta=333.8s
# [Composed:bdu_gru_run04] [530/3500] fps=8.9 eta=332.4s
# [Composed:bdu_gru_run04] [540/3500] fps=8.9 eta=331.5s
# [Composed:bdu_gru_run04] [550/3500] fps=8.9 eta=330.3s
# [Composed:bdu_gru_run04] [560/3500] fps=8.9 eta=329.1s
# [Composed:bdu_gru_run04] [570/3500] fps=8.9 eta=327.7s
# [Composed:bdu_gru_run04] [580/3500] fps=8.9 eta=326.6s
# [Composed:bdu_gru_run04] [590/3500] fps=8.9 eta=325.5s
# [Composed:bdu_gru_run04] [600/3500] fps=8.9 eta=324.4s
# [Composed:bdu_gru_run04] [610/3500] fps=8.9 eta=323.1s
# [Composed:bdu_gru_run04] [620/3500] fps=8.9 eta=322.1s
# [Composed:bdu_gru_run04] [630/3500] fps=8.9 eta=321.0s
# [Composed:bdu_gru_run04] [640/3500] fps=8.9 eta=320.1s
# [Composed:bdu_gru_run04] [650/3500] fps=8.9 eta=318.8s
# [Composed:bdu_gru_run04] [660/3500] fps=8.9 eta=317.6s
# [Composed:bdu_gru_run04] [670/3500] fps=8.9 eta=316.6s
# [Composed:bdu_gru_run04] [680/3500] fps=8.9 eta=315.5s
# [Composed:bdu_gru_run04] [690/3500] fps=8.9 eta=314.6s
# [Composed:bdu_gru_run04] [700/3500] fps=8.9 eta=313.3s
# [Composed:bdu_gru_run04] [710/3500] fps=8.9 eta=312.3s
# [Composed:bdu_gru_run04] [720/3500] fps=8.9 eta=311.2s
# [Composed:bdu_gru_run04] [730/3500] fps=8.9 eta=310.2s
# [Composed:bdu_gru_run04] [740/3500] fps=8.9 eta=309.0s
# [Composed:bdu_gru_run04] [750/3500] fps=8.9 eta=307.9s
# [Composed:bdu_gru_run04] [760/3500] fps=8.9 eta=306.8s
# [Composed:bdu_gru_run04] [770/3500] fps=8.9 eta=306.0s
# [Composed:bdu_gru_run04] [780/3500] fps=8.9 eta=305.0s
# [Composed:bdu_gru_run04] [790/3500] fps=8.9 eta=304.0s
# [Composed:bdu_gru_run04] [800/3500] fps=8.9 eta=302.9s
# [Composed:bdu_gru_run04] [810/3500] fps=8.9 eta=301.9s
# [Composed:bdu_gru_run04] [820/3500] fps=8.9 eta=301.0s
# [Composed:bdu_gru_run04] [830/3500] fps=8.9 eta=299.9s
# [Composed:bdu_gru_run04] [840/3500] fps=8.9 eta=298.9s
# [Composed:bdu_gru_run04] [850/3500] fps=8.9 eta=297.8s
# [Composed:bdu_gru_run04] [860/3500] fps=8.9 eta=296.5s
# [Composed:bdu_gru_run04] [870/3500] fps=8.9 eta=295.5s
# [Composed:bdu_gru_run04] [880/3500] fps=8.9 eta=294.3s
# [Composed:bdu_gru_run04] [890/3500] fps=8.9 eta=293.1s
# [Composed:bdu_gru_run04] [900/3500] fps=8.9 eta=291.9s
# [Composed:bdu_gru_run04] [910/3500] fps=8.9 eta=291.0s
# [Composed:bdu_gru_run04] [920/3500] fps=8.9 eta=289.7s
# [Composed:bdu_gru_run04] [930/3500] fps=8.9 eta=288.6s
# [Composed:bdu_gru_run04] [940/3500] fps=8.9 eta=287.4s
# [Composed:bdu_gru_run04] [950/3500] fps=8.9 eta=286.3s
# [Composed:bdu_gru_run04] [960/3500] fps=8.9 eta=285.1s
# [Composed:bdu_gru_run04] [970/3500] fps=8.9 eta=284.0s
# [Composed:bdu_gru_run04] [980/3500] fps=8.9 eta=283.0s
# [Composed:bdu_gru_run04] [990/3500] fps=8.9 eta=281.8s
# [Composed:bdu_gru_run04] [1000/3500] fps=8.9 eta=280.7s
# [Composed:bdu_gru_run04] [1010/3500] fps=8.9 eta=279.6s
# [Composed:bdu_gru_run04] [1020/3500] fps=8.9 eta=278.4s
# [Composed:bdu_gru_run04] [1030/3500] fps=8.9 eta=277.2s
# [Composed:bdu_gru_run04] [1040/3500] fps=8.9 eta=276.1s
# [Composed:bdu_gru_run04] [1050/3500] fps=8.9 eta=274.9s
# [Composed:bdu_gru_run04] [1060/3500] fps=8.9 eta=273.8s
# [Composed:bdu_gru_run04] [1070/3500] fps=8.9 eta=272.6s
# [Composed:bdu_gru_run04] [1080/3500] fps=8.9 eta=271.5s
# [Composed:bdu_gru_run04] [1090/3500] fps=8.9 eta=270.2s
# [Composed:bdu_gru_run04] [1100/3500] fps=8.9 eta=269.2s
# [Composed:bdu_gru_run04] [1110/3500] fps=8.9 eta=268.0s
# [Composed:bdu_gru_run04] [1120/3500] fps=8.9 eta=266.9s
# [Composed:bdu_gru_run04] [1130/3500] fps=8.9 eta=265.8s
# [Composed:bdu_gru_run04] [1140/3500] fps=8.9 eta=264.6s
# [Composed:bdu_gru_run04] [1150/3500] fps=8.9 eta=263.5s
# [Composed:bdu_gru_run04] [1160/3500] fps=8.9 eta=262.4s
# [Composed:bdu_gru_run04] [1170/3500] fps=8.9 eta=261.3s
# [Composed:bdu_gru_run04] [1180/3500] fps=8.9 eta=260.1s
# [Composed:bdu_gru_run04] [1190/3500] fps=8.9 eta=258.9s
# [Composed:bdu_gru_run04] [1200/3500] fps=8.9 eta=257.7s
# [Composed:bdu_gru_run04] [1210/3500] fps=8.9 eta=256.6s
# [Composed:bdu_gru_run04] [1220/3500] fps=8.9 eta=255.5s
# [Composed:bdu_gru_run04] [1230/3500] fps=8.9 eta=254.4s
# [Composed:bdu_gru_run04] [1240/3500] fps=8.9 eta=253.3s
# [Composed:bdu_gru_run04] [1250/3500] fps=8.9 eta=252.1s
# [Composed:bdu_gru_run04] [1260/3500] fps=8.9 eta=251.0s
# [Composed:bdu_gru_run04] [1270/3500] fps=8.9 eta=249.8s
# [Composed:bdu_gru_run04] [1280/3500] fps=8.9 eta=248.6s
# [Composed:bdu_gru_run04] [1290/3500] fps=8.9 eta=247.5s
# [Composed:bdu_gru_run04] [1300/3500] fps=8.9 eta=246.3s
# [Composed:bdu_gru_run04] [1310/3500] fps=8.9 eta=245.1s
# [Composed:bdu_gru_run04] [1320/3500] fps=8.9 eta=243.9s
# [Composed:bdu_gru_run04] [1330/3500] fps=8.9 eta=242.7s
# [Composed:bdu_gru_run04] [1340/3500] fps=8.9 eta=241.6s
# [Composed:bdu_gru_run04] [1350/3500] fps=8.9 eta=240.4s
# [Composed:bdu_gru_run04] [1360/3500] fps=8.9 eta=239.2s
# [Composed:bdu_gru_run04] [1370/3500] fps=8.9 eta=238.1s
# [Composed:bdu_gru_run04] [1380/3500] fps=8.9 eta=236.9s
# [Composed:bdu_gru_run04] [1390/3500] fps=8.9 eta=235.8s
# [Composed:bdu_gru_run04] [1400/3500] fps=9.0 eta=234.6s
# [Composed:bdu_gru_run04] [1410/3500] fps=9.0 eta=233.4s
# [Composed:bdu_gru_run04] [1420/3500] fps=9.0 eta=232.2s
# [Composed:bdu_gru_run04] [1430/3500] fps=9.0 eta=231.2s
# [Composed:bdu_gru_run04] [1440/3500] fps=9.0 eta=230.0s
# [Composed:bdu_gru_run04] [1450/3500] fps=9.0 eta=228.9s
# [Composed:bdu_gru_run04] [1460/3500] fps=9.0 eta=227.7s
# [Composed:bdu_gru_run04] [1470/3500] fps=9.0 eta=226.6s
# [Composed:bdu_gru_run04] [1480/3500] fps=9.0 eta=225.5s
# [Composed:bdu_gru_run04] [1490/3500] fps=9.0 eta=224.3s
# [Composed:bdu_gru_run04] [1500/3500] fps=9.0 eta=223.2s
# [Composed:bdu_gru_run04] [1510/3500] fps=9.0 eta=222.0s
# [Composed:bdu_gru_run04] [1520/3500] fps=9.0 eta=221.0s
# [Composed:bdu_gru_run04] [1530/3500] fps=9.0 eta=219.9s
# [Composed:bdu_gru_run04] [1540/3500] fps=9.0 eta=218.7s
# [Composed:bdu_gru_run04] [1550/3500] fps=9.0 eta=217.6s
# [Composed:bdu_gru_run04] [1560/3500] fps=9.0 eta=216.4s
# [Composed:bdu_gru_run04] [1570/3500] fps=9.0 eta=215.3s
# [Composed:bdu_gru_run04] [1580/3500] fps=9.0 eta=214.2s
# [Composed:bdu_gru_run04] [1590/3500] fps=9.0 eta=213.0s
# [Composed:bdu_gru_run04] [1600/3500] fps=9.0 eta=211.9s
# [Composed:bdu_gru_run04] [1610/3500] fps=9.0 eta=210.8s
# [Composed:bdu_gru_run04] [1620/3500] fps=9.0 eta=209.7s
# [Composed:bdu_gru_run04] [1630/3500] fps=9.0 eta=208.5s
# [Composed:bdu_gru_run04] [1640/3500] fps=9.0 eta=207.4s
# [Composed:bdu_gru_run04] [1650/3500] fps=9.0 eta=206.3s
# [Composed:bdu_gru_run04] [1660/3500] fps=9.0 eta=205.2s
# [Composed:bdu_gru_run04] [1670/3500] fps=9.0 eta=204.1s
# [Composed:bdu_gru_run04] [1680/3500] fps=9.0 eta=203.0s
# [Composed:bdu_gru_run04] [1690/3500] fps=9.0 eta=201.9s
# [Composed:bdu_gru_run04] [1700/3500] fps=9.0 eta=200.8s
# [Composed:bdu_gru_run04] [1710/3500] fps=9.0 eta=199.7s
# [Composed:bdu_gru_run04] [1720/3500] fps=9.0 eta=198.5s
# [Composed:bdu_gru_run04] [1730/3500] fps=9.0 eta=197.4s
# [Composed:bdu_gru_run04] [1740/3500] fps=9.0 eta=196.3s
# [Composed:bdu_gru_run04] [1750/3500] fps=9.0 eta=195.2s
# [Composed:bdu_gru_run04] [1760/3500] fps=9.0 eta=194.2s
# [Composed:bdu_gru_run04] [1770/3500] fps=9.0 eta=193.0s
# [Composed:bdu_gru_run04] [1780/3500] fps=9.0 eta=191.9s
# [Composed:bdu_gru_run04] [1790/3500] fps=9.0 eta=190.8s
# [Composed:bdu_gru_run04] [1800/3500] fps=9.0 eta=189.7s
# [Composed:bdu_gru_run04] [1810/3500] fps=9.0 eta=188.5s
# [Composed:bdu_gru_run04] [1820/3500] fps=9.0 eta=187.4s
# [Composed:bdu_gru_run04] [1830/3500] fps=9.0 eta=186.3s
# [Composed:bdu_gru_run04] [1840/3500] fps=9.0 eta=185.2s
# [Composed:bdu_gru_run04] [1850/3500] fps=9.0 eta=184.1s
# [Composed:bdu_gru_run04] [1860/3500] fps=9.0 eta=183.0s
# [Composed:bdu_gru_run04] [1870/3500] fps=9.0 eta=181.9s
# [Composed:bdu_gru_run04] [1880/3500] fps=9.0 eta=180.8s
# [Composed:bdu_gru_run04] [1890/3500] fps=9.0 eta=179.7s
# [Composed:bdu_gru_run04] [1900/3500] fps=9.0 eta=178.6s
# [Composed:bdu_gru_run04] [1910/3500] fps=9.0 eta=177.5s
# [Composed:bdu_gru_run04] [1920/3500] fps=9.0 eta=176.3s
# [Composed:bdu_gru_run04] [1930/3500] fps=9.0 eta=175.2s
# [Composed:bdu_gru_run04] [1940/3500] fps=9.0 eta=174.1s
# [Composed:bdu_gru_run04] [1950/3500] fps=9.0 eta=173.0s
# [Composed:bdu_gru_run04] [1960/3500] fps=9.0 eta=171.9s
# [Composed:bdu_gru_run04] [1970/3500] fps=9.0 eta=170.7s
# [Composed:bdu_gru_run04] [1980/3500] fps=9.0 eta=169.6s
# [Composed:bdu_gru_run04] [1990/3500] fps=9.0 eta=168.5s
# [Composed:bdu_gru_run04] [2000/3500] fps=9.0 eta=167.3s
# [Composed:bdu_gru_run04] [2010/3500] fps=9.0 eta=166.2s
# [Composed:bdu_gru_run04] [2020/3500] fps=9.0 eta=165.1s
# [Composed:bdu_gru_run04] [2030/3500] fps=9.0 eta=164.0s
# [Composed:bdu_gru_run04] [2040/3500] fps=9.0 eta=162.9s
# [Composed:bdu_gru_run04] [2050/3500] fps=9.0 eta=161.8s
# [Composed:bdu_gru_run04] [2060/3500] fps=9.0 eta=160.7s
# [Composed:bdu_gru_run04] [2070/3500] fps=9.0 eta=159.5s
# [Composed:bdu_gru_run04] [2080/3500] fps=9.0 eta=158.4s
# [Composed:bdu_gru_run04] [2090/3500] fps=9.0 eta=157.3s
# [Composed:bdu_gru_run04] [2100/3500] fps=9.0 eta=156.2s
# [Composed:bdu_gru_run04] [2110/3500] fps=9.0 eta=155.0s
# [Composed:bdu_gru_run04] [2120/3500] fps=9.0 eta=153.9s
# [Composed:bdu_gru_run04] [2130/3500] fps=9.0 eta=152.8s
# [Composed:bdu_gru_run04] [2140/3500] fps=9.0 eta=151.8s
# [Composed:bdu_gru_run04] [2150/3500] fps=9.0 eta=150.6s
# [Composed:bdu_gru_run04] [2160/3500] fps=9.0 eta=149.5s
# [Composed:bdu_gru_run04] [2170/3500] fps=9.0 eta=148.4s
# [Composed:bdu_gru_run04] [2180/3500] fps=9.0 eta=147.3s
# [Composed:bdu_gru_run04] [2190/3500] fps=9.0 eta=146.1s
# [Composed:bdu_gru_run04] [2200/3500] fps=9.0 eta=145.0s
# [Composed:bdu_gru_run04] [2210/3500] fps=9.0 eta=143.9s
# [Composed:bdu_gru_run04] [2220/3500] fps=9.0 eta=142.8s
# [Composed:bdu_gru_run04] [2230/3500] fps=9.0 eta=141.7s
# [Composed:bdu_gru_run04] [2240/3500] fps=9.0 eta=140.6s
# [Composed:bdu_gru_run04] [2250/3500] fps=9.0 eta=139.5s
# [Composed:bdu_gru_run04] [2260/3500] fps=9.0 eta=138.3s
# [Composed:bdu_gru_run04] [2270/3500] fps=9.0 eta=137.2s
# [Composed:bdu_gru_run04] [2280/3500] fps=9.0 eta=136.1s
# [Composed:bdu_gru_run04] [2290/3500] fps=9.0 eta=135.0s
# [Composed:bdu_gru_run04] [2300/3500] fps=9.0 eta=134.0s
# [Composed:bdu_gru_run04] [2310/3500] fps=9.0 eta=132.9s
# [Composed:bdu_gru_run04] [2320/3500] fps=9.0 eta=131.8s
# [Composed:bdu_gru_run04] [2330/3500] fps=9.0 eta=130.6s
# [Composed:bdu_gru_run04] [2340/3500] fps=9.0 eta=129.5s
# [Composed:bdu_gru_run04] [2350/3500] fps=9.0 eta=128.4s
# [Composed:bdu_gru_run04] [2360/3500] fps=9.0 eta=127.3s
# [Composed:bdu_gru_run04] [2370/3500] fps=9.0 eta=126.2s
# [Composed:bdu_gru_run04] [2380/3500] fps=9.0 eta=125.1s
# [Composed:bdu_gru_run04] [2390/3500] fps=9.0 eta=124.0s
# [Composed:bdu_gru_run04] [2400/3500] fps=8.9 eta=122.9s
# [Composed:bdu_gru_run04] [2410/3500] fps=8.9 eta=121.8s
# [Composed:bdu_gru_run04] [2420/3500] fps=9.0 eta=120.7s
# [Composed:bdu_gru_run04] [2430/3500] fps=9.0 eta=119.5s
# [Composed:bdu_gru_run04] [2440/3500] fps=9.0 eta=118.4s
# [Composed:bdu_gru_run04] [2450/3500] fps=9.0 eta=117.3s
# [Composed:bdu_gru_run04] [2460/3500] fps=9.0 eta=116.2s
# [Composed:bdu_gru_run04] [2470/3500] fps=9.0 eta=115.0s
# [Composed:bdu_gru_run04] [2480/3500] fps=9.0 eta=113.9s
# [Composed:bdu_gru_run04] [2490/3500] fps=9.0 eta=112.8s
# [Composed:bdu_gru_run04] [2500/3500] fps=9.0 eta=111.6s
# [Composed:bdu_gru_run04] [2510/3500] fps=9.0 eta=110.5s
# [Composed:bdu_gru_run04] [2520/3500] fps=9.0 eta=109.3s
# [Composed:bdu_gru_run04] [2530/3500] fps=9.0 eta=108.2s
# [Composed:bdu_gru_run04] [2540/3500] fps=9.0 eta=107.1s
# [Composed:bdu_gru_run04] [2550/3500] fps=9.0 eta=105.9s
# [Composed:bdu_gru_run04] [2560/3500] fps=9.0 eta=104.8s
# [Composed:bdu_gru_run04] [2570/3500] fps=9.0 eta=103.7s
# [Composed:bdu_gru_run04] [2580/3500] fps=9.0 eta=102.5s
# [Composed:bdu_gru_run04] [2590/3500] fps=9.0 eta=101.4s
# [Composed:bdu_gru_run04] [2600/3500] fps=9.0 eta=100.3s
# [Composed:bdu_gru_run04] [2610/3500] fps=9.0 eta=99.2s
# [Composed:bdu_gru_run04] [2620/3500] fps=9.0 eta=98.0s
# [Composed:bdu_gru_run04] [2630/3500] fps=9.0 eta=96.9s
# [Composed:bdu_gru_run04] [2640/3500] fps=9.0 eta=95.8s
# [Composed:bdu_gru_run04] [2650/3500] fps=9.0 eta=94.7s
# [Composed:bdu_gru_run04] [2660/3500] fps=9.0 eta=93.5s
# [Composed:bdu_gru_run04] [2670/3500] fps=9.0 eta=92.4s
# [Composed:bdu_gru_run04] [2680/3500] fps=9.0 eta=91.3s
# [Composed:bdu_gru_run04] [2690/3500] fps=9.0 eta=90.2s
# [Composed:bdu_gru_run04] [2700/3500] fps=9.0 eta=89.0s
# [Composed:bdu_gru_run04] [2710/3500] fps=9.0 eta=87.9s
# [Composed:bdu_gru_run04] [2720/3500] fps=9.0 eta=86.8s
# [Composed:bdu_gru_run04] [2730/3500] fps=9.0 eta=85.7s
# [Composed:bdu_gru_run04] [2740/3500] fps=9.0 eta=84.6s
# [Composed:bdu_gru_run04] [2750/3500] fps=9.0 eta=83.4s
# [Composed:bdu_gru_run04] [2760/3500] fps=9.0 eta=82.3s
# [Composed:bdu_gru_run04] [2770/3500] fps=9.0 eta=81.2s
# [Composed:bdu_gru_run04] [2780/3500] fps=9.0 eta=80.1s
# [Composed:bdu_gru_run04] [2790/3500] fps=9.0 eta=79.0s
# [Composed:bdu_gru_run04] [2800/3500] fps=9.0 eta=77.8s
# [Composed:bdu_gru_run04] [2810/3500] fps=9.0 eta=76.7s
# [Composed:bdu_gru_run04] [2820/3500] fps=9.0 eta=75.6s
# [Composed:bdu_gru_run04] [2830/3500] fps=9.0 eta=74.5s
# [Composed:bdu_gru_run04] [2840/3500] fps=9.0 eta=73.4s
# [Composed:bdu_gru_run04] [2850/3500] fps=9.0 eta=72.3s
# [Composed:bdu_gru_run04] [2860/3500] fps=9.0 eta=71.2s
# [Composed:bdu_gru_run04] [2870/3500] fps=9.0 eta=70.0s
# [Composed:bdu_gru_run04] [2880/3500] fps=9.0 eta=68.9s
# [Composed:bdu_gru_run04] [2890/3500] fps=9.0 eta=67.8s
# [Composed:bdu_gru_run04] [2900/3500] fps=9.0 eta=66.7s
# [Composed:bdu_gru_run04] [2910/3500] fps=9.0 eta=65.6s
# [Composed:bdu_gru_run04] [2920/3500] fps=9.0 eta=64.5s
# [Composed:bdu_gru_run04] [2930/3500] fps=9.0 eta=63.4s
# [Composed:bdu_gru_run04] [2940/3500] fps=9.0 eta=62.2s
# [Composed:bdu_gru_run04] [2950/3500] fps=9.0 eta=61.1s
# [Composed:bdu_gru_run04] [2960/3500] fps=9.0 eta=60.0s
# [Composed:bdu_gru_run04] [2970/3500] fps=9.0 eta=58.9s
# [Composed:bdu_gru_run04] [2980/3500] fps=9.0 eta=57.8s
# [Composed:bdu_gru_run04] [2990/3500] fps=9.0 eta=56.6s
# [Composed:bdu_gru_run04] [3000/3500] fps=9.0 eta=55.5s
# [Composed:bdu_gru_run04] [3010/3500] fps=9.0 eta=54.4s
# [Composed:bdu_gru_run04] [3020/3500] fps=9.0 eta=53.3s
# [Composed:bdu_gru_run04] [3030/3500] fps=9.0 eta=52.2s
# [Composed:bdu_gru_run04] [3040/3500] fps=9.0 eta=51.1s
# [Composed:bdu_gru_run04] [3050/3500] fps=9.0 eta=50.0s
# [Composed:bdu_gru_run04] [3060/3500] fps=9.0 eta=48.9s
# [Composed:bdu_gru_run04] [3070/3500] fps=9.0 eta=47.8s
# [Composed:bdu_gru_run04] [3080/3500] fps=9.0 eta=46.7s
# [Composed:bdu_gru_run04] [3090/3500] fps=9.0 eta=45.5s
# [Composed:bdu_gru_run04] [3100/3500] fps=9.0 eta=44.4s
# [Composed:bdu_gru_run04] [3110/3500] fps=9.0 eta=43.3s
# [Composed:bdu_gru_run04] [3120/3500] fps=9.0 eta=42.2s
# [Composed:bdu_gru_run04] [3130/3500] fps=9.0 eta=41.1s
# [Composed:bdu_gru_run04] [3140/3500] fps=9.0 eta=40.0s
# [Composed:bdu_gru_run04] [3150/3500] fps=9.0 eta=38.9s
# [Composed:bdu_gru_run04] [3160/3500] fps=9.0 eta=37.8s
# [Composed:bdu_gru_run04] [3170/3500] fps=9.0 eta=36.7s
# [Composed:bdu_gru_run04] [3180/3500] fps=9.0 eta=35.6s
# [Composed:bdu_gru_run04] [3190/3500] fps=9.0 eta=34.5s
# [Composed:bdu_gru_run04] [3200/3500] fps=9.0 eta=33.4s
# [Composed:bdu_gru_run04] [3210/3500] fps=9.0 eta=32.2s
# [Composed:bdu_gru_run04] [3220/3500] fps=9.0 eta=31.1s
# [Composed:bdu_gru_run04] [3230/3500] fps=9.0 eta=30.0s
# [Composed:bdu_gru_run04] [3240/3500] fps=9.0 eta=28.9s
# [Composed:bdu_gru_run04] [3250/3500] fps=9.0 eta=27.8s
# [Composed:bdu_gru_run04] [3260/3500] fps=9.0 eta=26.7s
# [Composed:bdu_gru_run04] [3270/3500] fps=9.0 eta=25.6s
# [Composed:bdu_gru_run04] [3280/3500] fps=9.0 eta=24.5s
# [Composed:bdu_gru_run04] [3290/3500] fps=9.0 eta=23.4s
# [Composed:bdu_gru_run04] [3300/3500] fps=9.0 eta=22.2s
# [Composed:bdu_gru_run04] [3310/3500] fps=9.0 eta=21.1s
# [Composed:bdu_gru_run04] [3320/3500] fps=9.0 eta=20.0s
# [Composed:bdu_gru_run04] [3330/3500] fps=9.0 eta=18.9s
# [Composed:bdu_gru_run04] [3340/3500] fps=9.0 eta=17.8s
# [Composed:bdu_gru_run04] [3350/3500] fps=9.0 eta=16.7s
# [Composed:bdu_gru_run04] [3360/3500] fps=9.0 eta=15.6s
# [Composed:bdu_gru_run04] [3370/3500] fps=9.0 eta=14.5s
# [Composed:bdu_gru_run04] [3380/3500] fps=9.0 eta=13.3s
# [Composed:bdu_gru_run04] [3390/3500] fps=9.0 eta=12.2s
# [Composed:bdu_gru_run04] [3400/3500] fps=9.0 eta=11.1s
# [Composed:bdu_gru_run04] [3410/3500] fps=9.0 eta=10.0s
# [Composed:bdu_gru_run04] [3420/3500] fps=9.0 eta=8.9s
# [Composed:bdu_gru_run04] [3430/3500] fps=9.0 eta=7.8s
# [Composed:bdu_gru_run04] [3440/3500] fps=9.0 eta=6.7s
# [Composed:bdu_gru_run04] [3450/3500] fps=9.0 eta=5.6s
# [Composed:bdu_gru_run04] [3460/3500] fps=9.0 eta=4.4s
# [Composed:bdu_gru_run04] [3470/3500] fps=9.0 eta=3.3s
# [Composed:bdu_gru_run04] [3480/3500] fps=9.0 eta=2.2s
# [Composed:bdu_gru_run04] [3490/3500] fps=9.0 eta=1.1s
# [Composed:bdu_gru_run04] [3500/3500] fps=9.0 eta=0.0s
# [Composed:bdu_gru_run04] done in 389.4s (9.0 FPS).
#
# FPS summary:
#   e2e_1epoch: 36.7 FPS
#   bdu_gru_search_02: 9.0 FPS
#   bdu_gru_run02: 8.9 FPS
#   bdu_gru_run04: 9.0 FPS

# %% [markdown]
# ## Results — MSE + Risk Plot
#
# ### MSE Computation

# %%
import matplotlib.patheffects as pe

def _masked_mse(pred: np.ndarray, target: np.ndarray) -> float:
    mask = np.isfinite(pred) & np.isfinite(target)
    return float(np.mean((pred[mask] - target[mask]) ** 2)) if np.any(mask) else float("nan")

x = np.asarray(used_frame_ids, dtype=np.int64)
real_arr = np.asarray(real_vals, dtype=np.float32)

e2e_arr_by_model = {k: np.asarray(v, dtype=np.float32) for k, v in e2e_preds_by_model.items()} if run_e2e else {}
composed_arr_by_model = {k: np.asarray(v, dtype=np.float32) for k, v in composed_preds_by_model.items()} if run_composed else {}

# --- Exponential-moving-average smoothing of the composed risk stream ---
# The composed predictor is temporally noisier than E2E (single-frame jitter and
# occasional spikes). A causal EMA filter on its output cleans the trace without
# look-ahead. alpha in (0, 1]; lower = smoother. Set EMA_ALPHA = 1.0 to disable.
EMA_ALPHA = 0.3


def _ema(arr: np.ndarray, alpha: float) -> np.ndarray:
    if alpha >= 1.0 or arr.size == 0:
        return arr
    out = np.empty_like(arr, dtype=np.float32)
    prev = np.nan
    for i, v in enumerate(arr):
        if not np.isfinite(v):
            out[i] = prev  # carry last good value through warm-up / gaps
            continue
        prev = v if not np.isfinite(prev) else alpha * v + (1.0 - alpha) * prev
        out[i] = prev
    return out


composed_smoothed_by_model = {k: _ema(arr, EMA_ALPHA) for k, arr in composed_arr_by_model.items()}

e2e_mse_by_model = {k: _masked_mse(arr, real_arr) for k, arr in e2e_arr_by_model.items()}
composed_mse_by_model = {k: _masked_mse(arr, real_arr) for k, arr in composed_arr_by_model.items()}
composed_smoothed_mse_by_model = {k: _masked_mse(arr, real_arr) for k, arr in composed_smoothed_by_model.items()}

best_name = min(composed_mse_by_model, key=composed_mse_by_model.get) if composed_mse_by_model else None

print("E2E MSE:"); [print(f"  {k}: {v:.6f}") for k, v in e2e_mse_by_model.items()]
print("Composed MSE (raw):"); [print(f"  {k}: {v:.6f}") for k, v in composed_mse_by_model.items()]
print(f"Composed MSE (EMA alpha={EMA_ALPHA}):"); [print(f"  {k}: {v:.6f}") for k, v in composed_smoothed_mse_by_model.items()]
# Out:
# E2E MSE:
#   e2e_1epoch: 3.421880
# Composed MSE (raw):
#   bdu_gru_search_02: 4.800702
#   bdu_gru_run02: 3.701749
#   bdu_gru_run04: 3.640994
# Composed MSE (EMA alpha=0.3):
#   bdu_gru_search_02: 4.568956
#   bdu_gru_run02: 3.572740
#   bdu_gru_run04: 3.592719
# [None, None, None]

# %% [markdown]
# ### Interactive Risk Plot

# %%
plot_mode = "manual_highlight"  # "manual_highlight", "interactive_selector", "highlight_best", "show_all"
default_checkpoint = "all"
# For plot_mode == "manual_highlight": draws a static (saveable) figure with one
# composed model emphasised. Set to a checkpoint name, an integer index (0..N-1
# over the sorted composed checkpoints), or "all" to emphasise none.
highlight_selection = 1
show_smoothed_composed = True   # plot the EMA-smoothed composed trace instead of the raw one
show_raw_composed_faint = True  # also draw the raw composed trace faintly underneath

_e2e_color_list = ["tab:blue", "tab:cyan", "tab:purple", "tab:olive"]


def _resolve_highlight(selection) -> str:
    """Map a name / integer index / 'all' to a composed checkpoint name."""
    names = sorted(composed_arr_by_model.keys())
    if selection is None or selection == "all":
        return "all"
    if isinstance(selection, int) or (isinstance(selection, str) and selection.lstrip("-").isdigit()):
        i = int(selection)
        if not names:
            return "all"
        if not (0 <= i < len(names)):
            raise IndexError(f"highlight index {i} out of range [0, {len(names) - 1}]")
        return names[i]
    if selection in composed_arr_by_model:
        return selection
    raise KeyError(f"highlight '{selection}' not found. Options: {names}")


def _draw_plot(selected_checkpoint: str = "all") -> None:
    plt.figure(figsize=(14, 6))
    plt.plot(x, real_arr, label="Real Risk", linewidth=2.8, color="black")

    for idx, (name, arr) in enumerate(e2e_arr_by_model.items()):
        color = _e2e_color_list[idx % len(_e2e_color_list)]
        line, = plt.plot(x, arr, label=f"E2E {name}", linewidth=2.2, color=color)
        line.set_path_effects([pe.Stroke(linewidth=4.0, foreground="white"), pe.Normal()])

    cmap = plt.cm.get_cmap("tab10")
    # In manual_highlight, draw every model but emphasise only the selected one;
    # in interactive_selector, hide the non-selected models entirely.
    emphasise_only = plot_mode in {"manual_highlight", "highlight_best"}
    for idx, (name, raw_arr) in enumerate(composed_arr_by_model.items()):
        show = emphasise_only or selected_checkpoint == "all" or selected_checkpoint == name
        if not show:
            continue
        is_em = selected_checkpoint == name or (plot_mode == "highlight_best" and name == best_name)
        lw = 2.8 if is_em else 1.4
        color = cmap(idx % 10)
        pred_arr = composed_smoothed_by_model[name] if show_smoothed_composed else raw_arr
        if show_smoothed_composed and show_raw_composed_faint:
            plt.plot(x, raw_arr, linewidth=0.8, alpha=0.25, color=color, zorder=1)
        label = f"Composed {name}" + (f" (EMA {EMA_ALPHA})" if show_smoothed_composed else "")
        line, = plt.plot(x, pred_arr, label=label, linewidth=lw,
                         alpha=1.0 if is_em else 0.7, color=color, zorder=5 if is_em else 2)
        if is_em:
            line.set_path_effects([pe.Stroke(linewidth=lw + 2.0, foreground="black"), pe.Normal()])

    if len(x) >= Config.INFERENCE_SEQUENCE_LENGTH:
        plt.axvline(x=x[Config.INFERENCE_SEQUENCE_LENGTH - 1], color="gray", linestyle="--", alpha=0.5, label="Warmup Complete")

    plt.xlabel("Frame ID"); plt.ylabel("Risk")
    title = f"Risk Comparison | {selected_scenario_dir.name} | {len(x)} frames"
    if selected_checkpoint != "all":
        title += f"\n{selected_checkpoint}"
    plt.title(title)
    plt.legend(loc="upper right", ncol=2, fontsize=8)
    plt.tight_layout()
    plt.show()


if run_composed and composed_arr_by_model and plot_mode == "manual_highlight":
    _hl = _resolve_highlight(highlight_selection)
    print(f"Highlighting: {_hl}")
    _draw_plot(_hl)
elif run_composed and composed_arr_by_model and plot_mode == "interactive_selector":
    try:
        import ipywidgets as widgets
        from IPython.display import display as ipy_display
        options = ["all"] + sorted(composed_arr_by_model.keys())
        selector = widgets.Dropdown(options=options, value="all", description="Checkpoint:", layout=widgets.Layout(width="320px"))
        ipy_display(widgets.VBox([selector, widgets.interactive_output(_draw_plot, {"selected_checkpoint": selector})]))
    except Exception as exc:
        print(f"Interactive selector unavailable ({exc}). Using static plot.")
        _draw_plot(default_checkpoint)
else:
    _draw_plot(default_checkpoint)
# Out:
# Highlighting: bdu_gru_run04
# C:\Users\mique\AppData\Local\Temp\ipykernel_26904\479986954.py:39: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10")

# %% [markdown]
# ## Town05 Overlay (Sets 17 to 21)
# Compare two Town05 scenarios from sets 17 to 21 only, with predicted risk overlaid on top of real risk (Town10 excluded).

# %%
import re

overlay_max_frames = min(500, int(num_frames_to_plot))
overlay_e2e_keys = list(e2e_predictors.keys())
overlay_composed_keys = ["bdu_gru_search_02"]

_slot_re = re.compile(r"^(?P<set>\d{2})(?P<letter>[A-D])_")


def _is_town10(name: str) -> bool:
    return "town10" in name.lower()


def _scenario_crop_bbox(scenario_dir):
    """Read the dashboard crop the composed features were labeled with, from this
    scenario's dataset_labeled.jsonl. Returns None if unavailable (no crop)."""
    labeled = scenario_dir / "dataset_labeled.jsonl"
    if not labeled.is_file():
        return None
    for rec in load_jsonl_records(str(labeled)):
        bbox = rec.get("crop_bbox_xyxy")
        if isinstance(bbox, (list, tuple)) and len(bbox) == 4:
            return [float(v) for v in bbox]
    return None


def _load_scenario_series(scenario_dir, max_frames: int):
    recs = load_jsonl_records(str(scenario_dir / source_jsonl_name))
    paths, real = [], []
    for rec in recs:
        rel = str(rec.get("rgb_image_path", "")).strip()
        if not rel:
            continue
        full = resolve_image_path(str(scenario_dir), rel, normalize_paths=True)
        if not os.path.isfile(full):
            continue
        paths.append(full)
        real.append(float(rec.get("ground_truth_risk", 0.0)))
        if len(paths) >= max_frames:
            break
    if not paths:
        raise RuntimeError(f"No valid frames in {scenario_dir.name}")
    return paths, np.asarray(real, dtype=np.float32)


def _predict_series(predictor, frame_paths: list, tag: str) -> np.ndarray:
    predictor.reset_queue()
    preds = []
    for idx, fp in enumerate(frame_paths, start=1):
        out = predictor.add_image_path(fp)
        preds.append(float(out.latest_risk) if out.ready and out.latest_risk is not None else np.nan)
        if idx % 100 == 0 or idx == len(frame_paths):
            print(f"  [{tag}] {idx}/{len(frame_paths)}")
    return np.asarray(preds, dtype=np.float32)


def _mse(pred: np.ndarray, target: np.ndarray) -> float:
    mask = np.isfinite(pred) & np.isfinite(target)
    return float(np.mean((pred[mask] - target[mask]) ** 2)) if np.any(mask) else float("nan")

# %% [markdown]
# ## Town10 Overlay — Multi-Scenario Comparison
#
# Runs both models on two Town10 scenarios side by side.
#
# ### Helper Functions

# %% [markdown]
# ### Scenario Discovery + Frame Loading

# %%
# Build overlay predictor dict — load any missing composed checkpoints on demand
overlay_predictors = {}
for key in overlay_e2e_keys:
    if key in e2e_predictors:
        overlay_predictors[f"e2e:{key}"] = e2e_predictors[key]
for key in overlay_composed_keys:
    if key not in composed_predictors:
        if key in composed_checkpoint_paths and composed_checkpoint_paths[key].is_file():
            composed_predictors[key] = QueuedComposedBDUGRURiskInference.from_checkpoint(
                checkpoint_path=str(composed_checkpoint_paths[key]),
                feature_integrator=FeatureIntegrator(),
                yolo_model=yolo_model or YOLO(str(MODEL_PATHS["yolo"])),
                depth_estimator=depth_estimator,
                environment_predictor=environment_predictor,
                road_segmentation=road_segmentation,
                device=device_name,
            )
            print(f"Loaded on-demand: {key}")
    if key in composed_predictors:
        overlay_predictors[f"composed:{key}"] = composed_predictors[key]

if not overlay_predictors:
    raise RuntimeError("No overlay predictors available.")

# Pick two Town10 scenarios
town10_candidates = sorted([p for p in scenario_dirs if _is_town10(p.name)], key=lambda p: p.name)
if len(town10_candidates) < 2:
    raise RuntimeError(f"Need ≥2 Town10 scenarios, found: {[p.name for p in town10_candidates]}")

scenario_a = town10_candidates[0]
scenario_b = town10_candidates[-1] if town10_candidates[-1] != town10_candidates[0] else town10_candidates[1]

print(f"Scenario A: {scenario_a.name}")
print(f"Scenario B: {scenario_b.name}")

a_paths, a_real = _load_scenario_series(scenario_a, overlay_max_frames)
b_paths, b_real = _load_scenario_series(scenario_b, overlay_max_frames)
print(f"Loaded {len(a_paths)} / {len(b_paths)} frames from A / B.")
# Out:
# Scenario A: 17C_WetNoon_Town10HD_HighVol
# Scenario B: 21D_HardRainNoon_Town10HD_LowVol_NoFog_Night
# Loaded 500 / 500 frames from A / B.

# %% [markdown]
# ### Run Overlay Inference

# %%
a_preds_by_model, b_preds_by_model = {}, {}

# Composed predictors are cropped before perception; use the same fixed crop as
# NB_13 ([0, 0, 512, 305]) for every scenario so the overlay matches the trial
# pipeline. Set it (and clear the per-frame caches) before each series.
# E2E predictors ignore the crop.
crop_a = crop_b = [0, 0, 512, 305]
print(f"Crop A: {crop_a}  |  Crop B: {crop_b}")


def _predict_series_with_crop(predictor, frame_paths, tag, crop_bbox):
    if hasattr(predictor, "manual_crop_bbox"):
        predictor.manual_crop_bbox = normalize_crop_bbox_xyxy(crop_bbox)
        predictor.clear_preprocess_cache()
    return _predict_series(predictor, frame_paths, tag)


for model_name, predictor in overlay_predictors.items():
    print(f"\n--- {model_name} ---")
    a_preds_by_model[model_name] = _predict_series_with_crop(predictor, a_paths, f"A:{model_name}", crop_a)
    b_preds_by_model[model_name] = _predict_series_with_crop(predictor, b_paths, f"B:{model_name}", crop_b)

a_mse_by_model = {k: _mse(arr, a_real) for k, arr in a_preds_by_model.items()}
b_mse_by_model = {k: _mse(arr, b_real) for k, arr in b_preds_by_model.items()}

print("\nMSE summary:")
for name in overlay_predictors:
    print(f"  {name}: A={a_mse_by_model[name]:.6f}  B={b_mse_by_model[name]:.6f}")
# Out:
# --- e2e:e2e_latest ---
#   [A:e2e:e2e_latest] 100/500
#   [A:e2e:e2e_latest] 200/500
#   [A:e2e:e2e_latest] 300/500
#   [A:e2e:e2e_latest] 400/500
#   [A:e2e:e2e_latest] 500/500
#   [B:e2e:e2e_latest] 100/500
#   [B:e2e:e2e_latest] 200/500
#   [B:e2e:e2e_latest] 300/500
#   [B:e2e:e2e_latest] 400/500
#   [B:e2e:e2e_latest] 500/500
#
# --- e2e:e2e_1epoch ---
#   [A:e2e:e2e_1epoch] 100/500
#   [A:e2e:e2e_1epoch] 200/500
#   [A:e2e:e2e_1epoch] 300/500
#   [A:e2e:e2e_1epoch] 400/500
#   [A:e2e:e2e_1epoch] 500/500
#   [B:e2e:e2e_1epoch] 100/500
#   [B:e2e:e2e_1epoch] 200/500
#   [B:e2e:e2e_1epoch] 300/500
#   [B:e2e:e2e_1epoch] 400/500
#   [B:e2e:e2e_1epoch] 500/500
#
# --- composed:bdu_gru_search_02 ---
#   [A:composed:bdu_gru_search_02] 100/500
#   [A:composed:bdu_gru_search_02] 200/500
#   [A:composed:bdu_gru_search_02] 300/500
#   [A:composed:bdu_gru_search_02] 400/500
#   [A:composed:bdu_gru_search_02] 500/500
#   [B:composed:bdu_gru_search_02] 100/500
#   [B:composed:bdu_gru_search_02] 200/500
#   [B:composed:bdu_gru_search_02] 300/500
#   [B:composed:bdu_gru_search_02] 400/500
#   [B:composed:bdu_gru_search_02] 500/500
#
# MSE summary:
#   e2e:e2e_latest: A=7.113127  B=146.652039
#   e2e:e2e_1epoch: A=5.988370  B=65.532013
#   composed:bdu_gru_search_02: A=0.491438  B=21.253407

# %% [markdown]
# ### Interactive Side-by-Side Plot

# %%
_e2e_colors = ["tab:blue", "tab:cyan", "tab:purple", "tab:olive"]
_comp_colors = ["tab:orange", "tab:red", "tab:pink", "tab:brown"]
_overlay_colors = {}
_ei = _ci = 0
for name in overlay_predictors:
    if name.startswith("e2e:"):
        _overlay_colors[name] = _e2e_colors[_ei % len(_e2e_colors)]; _ei += 1
    else:
        _overlay_colors[name] = _comp_colors[_ci % len(_comp_colors)]; _ci += 1


def _draw_overlay(selected_model: str = "all") -> None:
    fig, (ax_a, ax_b) = plt.subplots(1, 2, figsize=(16, 5), sharey=True)

    for ax, real, preds_by_model, mse_by_model, scen_dir in [
        (ax_a, a_real, a_preds_by_model, a_mse_by_model, scenario_a),
        (ax_b, b_real, b_preds_by_model, b_mse_by_model, scenario_b),
    ]:
        x_ov = np.arange(len(real), dtype=np.int64)
        ax.plot(x_ov, real, label="Real Risk", linewidth=2.2, color="black")
        for name, arr in preds_by_model.items():
            if selected_model != "all" and selected_model != name:
                continue
            is_em = selected_model == name
            lw = 2.4 if is_em else 1.4
            line, = ax.plot(x_ov, arr,
                            label=f"{name} (MSE={mse_by_model.get(name, float('nan')):.5f})",
                            linewidth=lw, color=_overlay_colors.get(name, "gray"),
                            alpha=1.0 if is_em else 0.65, zorder=5 if is_em else 2)
            if is_em:
                line.set_path_effects([pe.Stroke(linewidth=lw + 2.0, foreground="black"), pe.Normal()])
        ax.set_xlabel("Frame Index"); ax.set_ylabel("Risk")
        ax.set_title(scen_dir.name)
        ax.legend(fontsize=7, loc="upper right")

    suffix = f" — {selected_model}" if selected_model != "all" else ""
    plt.suptitle(f"Town10 Risk Overlay{suffix}", fontsize=12)
    plt.tight_layout()
    plt.show()


try:
    import ipywidgets as widgets
    from IPython.display import display as ipy_display
    model_options = ["all"] + list(overlay_predictors.keys())
    selector = widgets.Dropdown(options=model_options, value="all", description="Model:", layout=widgets.Layout(width="360px"))
    ipy_display(widgets.VBox([selector, widgets.interactive_output(_draw_overlay, {"selected_model": selector})]))
except Exception as exc:
    print(f"Interactive selector unavailable ({exc}). Using static plot.")
    _draw_overlay("all")
# Out:
# VBox(children=(Dropdown(description='Model:', layout=Layout(width='360px'), options=('all', 'e2e:e2e_latest', …
