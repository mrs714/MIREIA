# %% [markdown]
# # NB_12_trial_function_batch_runner - Trial Batch Runner - Risk-Function Subtrials
#
# **Purpose.** Sweep every trial under ground-truth-risk-aware speed control: the speed policy reads the oracle's scalar risk and modulates target speed accordingly (no learned model in the loop).
#
# **Inputs.** trials authored with NB_08, a risk-function configuration (risk1, risk2, ...).
#
# **Outputs.** runs/<timestamp>_riskfnN/ folders and a batch summary.
#
# **How to run.** Pick a risk-function config in section 3, then run section 4. Re-run with different configs to compare them in NB_15.
#
# **Position in the workflow.** Oracle-in-the-loop counterpart to NB_13 (model-in-the-loop).

# %% [markdown]
# ## 0 — CARLA Launch

# %%
import subprocess

AUTO_LAUNCH_CARLA = True
CARLA_EXE = "CarlaUE4.exe"

if AUTO_LAUNCH_CARLA:
    subprocess.Popen(CARLA_EXE, shell=True)
    print(f"Launched {CARLA_EXE}")
else:
    print("AUTO_LAUNCH_CARLA is False. Assuming CARLA is already running.")
# Out:
# Launched CarlaUE4.exe

# %% [markdown]
# ## 1 — Imports

# %%
import sys
import time
from pathlib import Path

from MIREIA.config import Config
from MIREIA.core.speed_policy import KineticRiskSpeedPolicy
from MIREIA.simulation.trials import EgoTrialConfig, TrialDefinition, TrialRunner

# %% [markdown]
# ## 2 — Discover Trials

# %%
trials_root = Path(Config.PATH_TO_TRIALS)
all_trials = sorted(p.parent.name for p in trials_root.glob("*/trial.json") if p.is_file())

# Filtering (leave INCLUDE_PREFIXES empty to include every trial)
INCLUDE_PREFIXES: list[str] = []   # e.g. ["auto_"] to only run auto-generated trials
EXCLUDE_TRIALS:   list[str] = []   # exact trial names to skip

if INCLUDE_PREFIXES:
    selected_trial_names = [n for n in all_trials if any(n.startswith(p) for p in INCLUDE_PREFIXES)]
else:
    selected_trial_names = list(all_trials)
selected_trial_names = [n for n in selected_trial_names[:] if n not in EXCLUDE_TRIALS]

print(f"Found {len(all_trials)} trial(s); {len(selected_trial_names)} selected to run:")
for n in selected_trial_names:
    print(f"  - {n}")
# Out:
# Found 20 trial(s); 20 selected to run:
#   - auto_17A_WetNoon_Town05_HighVol
#   - auto_17B_WetNoon_Town05_LowVol
#   - auto_17C_WetNoon_Town10HD_HighVol
#   - auto_17D_WetNoon_Town10HD_LowVol
#   - auto_18A_MidRainyNoon_Town05_HighVol
#   - auto_18B_MidRainyNoon_Town05_LowVol
#   - auto_18C_MidRainyNoon_Town10HD_HighVol
#   - auto_18D_MidRainyNoon_Town10HD_LowVol
#   - auto_19A_CloudySunset_Town05_HighVol
#   - auto_19B_CloudySunset_Town05_LowVol
#   - auto_19C_CloudySunset_Town10HD_HighVol
#   - auto_19D_CloudySunset_Town10HD_LowVol
#   - auto_20A_SoftRainSunset_Town05_HighVol
#   - auto_20B_SoftRainSunset_Town05_LowVol
#   - auto_20C_SoftRainSunset_Town10HD_HighVol
#   - auto_20D_SoftRainSunset_Town10HD_LowVol
#   - auto_21A_ClearNoon_Town05_HighVol_NoFog_Night
#   - auto_21B_CloudyNoon_Town05_LowVol_NoFog_Night
#   - auto_21C_WetNoon_Town10HD_HighVol_NoFog_Night
#   - auto_21D_HardRainNoon_Town10HD_LowVol_NoFog_Night

# %% [markdown]
# ## 3 — Risk Function & Subtrial Config
#
# `risk_speed_fn(v, r)` returns the desired target speed (km/h) for that tick.
#
# - `v` (`v_target`) — live zone speed limit (km/h), read from CARLA every tick.
# - `r` — ground-truth scene risk; can be `None` if the oracle fails momentarily.
#
# ### Formula
#
# $$v_{safe} = \sqrt{\, v_{min}^2 + \bigl(v_{target}^2 - v_{min}^2\bigr) \cdot e^{-\lambda \cdot \max(0,\; R - R_{base})} \,}$$
#
# | Parameter | Variable | Role |
# |-----------|----------|------|
# | `R_BASE` | $R_{base}$ | Risk below this → exponent = 0 → $v_{safe} = v_{target}$ (no penalty). Raise it to ignore moderate-risk events |
# | `LAMBDA` | $\lambda$ | Aggressiveness: higher = steeper drop above the baseline |
# | `V_MIN_FACTOR` | $v_{min} = $ `V_MIN_FACTOR` $ \times v_{target}$ | Speed floor as a fraction of the zone limit; guarantees the car never fully stops |
#
# **Energy scaling:** the decay is applied to squared velocities so the first unit of excess risk removes the maximum possible kinetic energy — steeper non-linear response than a linear clamp.
#
# Set `selected_risk` below to one of `risk1 … risk5` (subtrial names `riskfn1 … riskfn5`). The preview after the cell samples the function at realistic GT-risk values (≈ 1–10+) so you can tune `R_BASE`, `LAMBDA`, and `V_MIN_FACTOR` before launching the batch.

# %%
risk1 = {
    "SUBTRIAL_NAME": "riskfn1",
    "SPEED_MULTIPLIER": 1.0,
    "MAX_STEPS_PER_TRIAL": 6000,
    "R_BASE": 3.0,           # ignore risk below this baseline (no slowdown)
    "LAMBDA": 1,             # response aggressiveness (higher = steeper drop above R_BASE)
    "V_MIN_FACTOR": 0.75,    # v_min = V_MIN_FACTOR * v_target (speed floor)
}

risk2 = {  # The least aggressive setting
    "SUBTRIAL_NAME": "riskfn2",
    "SPEED_MULTIPLIER": 1.0,
    "MAX_STEPS_PER_TRIAL": 6000,
    "R_BASE": 3.0,
    "LAMBDA": 0.5,
    "V_MIN_FACTOR": 0.85,
}

risk3 = {
    "SUBTRIAL_NAME": "riskfn3",
    "SPEED_MULTIPLIER": 1.0,
    "MAX_STEPS_PER_TRIAL": 6000,
    "R_BASE": 3.0,
    "LAMBDA": 2,
    "V_MIN_FACTOR": 0.55,
}

risk4 = {  # Delayed onset, sharp response: ignore moderate risk, react hard above R=5
    "SUBTRIAL_NAME": "riskfn4",
    "SPEED_MULTIPLIER": 1.0,
    "MAX_STEPS_PER_TRIAL": 6000,
    "R_BASE": 5.0,
    "LAMBDA": 2.5,
    "V_MIN_FACTOR": 0.55,
}

risk5 = {  # Same delayed onset as fn4 but cuts deeper when engaged (floor 0.45 instead of 0.55).
           # Tests whether the high-risk shortfall vs fn3 in heavy-rain scenarios (21D) closes
           # when we go below fn3's floor in the high-R regime.
    "SUBTRIAL_NAME": "riskfn5",
    "SPEED_MULTIPLIER": 1.0,
    "MAX_STEPS_PER_TRIAL": 6000,
    "R_BASE": 5.0,
    "LAMBDA": 2.5,
    "V_MIN_FACTOR": 0.45,
}



selected_risk = risk5
SUBTRIAL_NAME = selected_risk["SUBTRIAL_NAME"]
SPEED_MULTIPLIER = selected_risk["SPEED_MULTIPLIER"]
MAX_STEPS_PER_TRIAL = selected_risk["MAX_STEPS_PER_TRIAL"]
R_BASE = selected_risk["R_BASE"]
LAMBDA = selected_risk["LAMBDA"]
V_MIN_FACTOR = selected_risk["V_MIN_FACTOR"]

risk_speed_fn = KineticRiskSpeedPolicy(r_base=R_BASE, lam=LAMBDA, v_min_factor=V_MIN_FACTOR)

# Sanity-check the shape at realistic GT-risk values before launching.
print(risk_speed_fn.preview())

ego_cfg = EgoTrialConfig(
    name=SUBTRIAL_NAME,
    ego_blueprint="vehicle.lincoln.mkz_2020",
    # target_speed_kmh=None -> controller uses the live zone speed limit as v_target.
    speed_multiplier=SPEED_MULTIPLIER,
    use_vehicle_camera_defaults=True,
    controller_mode="behavior_agent",
    controller_behavior="normal",
)

runner = TrialRunner(verbose=False)
print(f"Risk-fn ego config ready: subtrial='{SUBTRIAL_NAME}', SPEED_MULTIPLIER={SPEED_MULTIPLIER}")
# Out:
# KineticRiskSpeedPolicy  r_base=5.0  lam=2.5  v_min_factor=0.45
#    v_target      R ->   v_safe   ratio
#        30.0   None ->    30.00   1.000
#        30.0    0.0 ->    30.00   1.000
#        30.0    4.0 ->    30.00   1.000
#        30.0    5.0 ->    30.00   1.000
#        30.0    6.0 ->    15.53   0.518
#        30.0    8.0 ->    13.51   0.450
#        30.0   12.0 ->    13.50   0.450
#        30.0   22.0 ->    13.50   0.450
#
#        50.0   None ->    50.00   1.000
#        50.0    0.0 ->    50.00   1.000
#        50.0    4.0 ->    50.00   1.000
#        50.0    5.0 ->    50.00   1.000
#        50.0    6.0 ->    25.88   0.518
#        50.0    8.0 ->    22.52   0.450
#        50.0   12.0 ->    22.50   0.450
#        50.0   22.0 ->    22.50   0.450
#
#        90.0   None ->    90.00   1.000
#        90.0    0.0 ->    90.00   1.000
#        90.0    4.0 ->    90.00   1.000
#        90.0    5.0 ->    90.00   1.000
#        90.0    6.0 ->    46.59   0.518
#        90.0    8.0 ->    40.54   0.450
#        90.0   12.0 ->    40.50   0.450
#        90.0   22.0 ->    40.50   0.450
#
# Risk-fn ego config ready: subtrial='riskfn5', SPEED_MULTIPLIER=1.0

# %% [markdown]
# ## 4 — Run Each Trial

# %%
all_summaries = []
failed: list[tuple[str, str]] = []

# --- Run-time accounting (sim vs wall, cap meaning) ----------------------------
# step  = one CARLA world.tick() = one fixed_delta seconds of simulated time.
# image_stride controls JSONL cadence, NOT loop iteration count.
# The loop exits early when controller.done() — ego reached the route end (within
# arrival_threshold_m = 3 m). max_steps is the cap; functions that slow the car
# more cover the same distance in MORE sim time, so they need a higher cap.
fixed_delta_s    = float(Config.SIM_FIXED_DELTA_SECONDS)
stride_ticks     = int(Config.RECORD_EVERY_N_TICKS)
sim_time_cap_s   = MAX_STEPS_PER_TRIAL * fixed_delta_s
max_jsonl_frames = MAX_STEPS_PER_TRIAL // stride_ticks
record_hz        = 1.0 / (fixed_delta_s * stride_ticks)

print("Run configuration:")
print(f"  subtrial_name:        '{SUBTRIAL_NAME}'")
print(f"  SPEED_MULTIPLIER:     {SPEED_MULTIPLIER:.3f}")
print(f"  risk source:          ground truth (wm.get_risk() per tick)")
print(f"  fixed_delta:          {fixed_delta_s:.3f} s/tick  ({1/fixed_delta_s:.1f} Hz physics)")
print(f"  image_stride:         {stride_ticks} ticks/frame  ({record_hz:.2f} Hz JSONL records)")
print(f"  max_steps_per_trial:  {MAX_STEPS_PER_TRIAL}  (cap = {sim_time_cap_s:.1f} s sim time, "
      f"<= {max_jsonl_frames} JSONL frames)")
print(f"  finished=True   -> controller reported done before the cap (good)")
print(f"  finished=False  -> hit max_steps cap (raise MAX_STEPS_PER_TRIAL or make risk_speed_fn faster)")

_progress_state: dict = {"trial_started": 0.0}

def _format_secs(s: float) -> str:
    if s < 60:
        return f"{s:5.1f}s"
    m, sec = divmod(s, 60)
    return f"{int(m):02d}:{int(sec):02d}"

def _on_progress(step: int, max_steps: int) -> None:
    now = time.time()
    last = _progress_state.get("last_print", 0.0)
    if now - last < 0.2:
        return
    _progress_state["last_print"] = now
    elapsed = now - _progress_state["trial_started"]
    rate = step / elapsed if elapsed > 0 else 0.0
    pct = 100.0 * step / max_steps if max_steps else 0.0
    eta_to_cap = (max_steps - step) / rate if rate > 0 else float("inf")
    speedup = (step * fixed_delta_s) / elapsed if elapsed > 0 else 0.0
    sys.stdout.write(
        f"\r    step {step:5d}/{max_steps} ({pct:5.1f}% of cap)  "
        f"wall={_format_secs(elapsed)}  "
        f"rate={rate:5.1f} t/s  "
        f"speedup={speedup:4.2f}x  "
        f"eta_to_cap={_format_secs(eta_to_cap) if rate > 0 else '  inf'}    "
    )
    sys.stdout.flush()

batch_started = time.time()
for idx, trial_name in enumerate(selected_trial_names, start=1):
    print()
    print(f">>> [{idx}/{len(selected_trial_names)}] {trial_name}", flush=True)
    _progress_state["trial_started"] = time.time()
    _progress_state["last_print"] = 0.0
    try:
        trial = TrialDefinition.load(trial_name)
        summary = runner.run_subtrial(
            trial=trial,
            ego_cfg=ego_cfg,
            max_steps=MAX_STEPS_PER_TRIAL,
            image_stride=Config.RECORD_EVERY_N_TICKS,
            store_rgb_images=False,
            store_topdown_images=False,
            store_risk_frame_images=False,
            store_static_risk_map=False,
            draw_debug_every_tick=False,
            risk_speed_fn=risk_speed_fn,
            use_ground_truth_risk=True,
            progress_callback=_on_progress,
            progress_every_n_steps=25,
        )
        elapsed = time.time() - _progress_state["trial_started"]
        sim_seconds = summary.num_frames * fixed_delta_s * stride_ticks
        speedup = sim_seconds / elapsed if elapsed > 0 else float("inf")
        sys.stdout.write("\r" + " " * 130 + "\r")
        sys.stdout.flush()
        print(
            f"    ok in {elapsed:6.1f}s wall  "
            f"frames={summary.num_frames:4d}  "
            f"sim_t={sim_seconds:6.1f}s  "
            f"speedup={speedup:5.2f}x  "
            f"dist={summary.traveled_m:7.1f}m  "
            f"risk_auc={summary.risk_auc:.3f}  "
            f"finished={summary.finished}"
        )
        all_summaries.append(summary)
    except Exception as e:
        elapsed = time.time() - _progress_state["trial_started"]
        sys.stdout.write("\r" + " " * 130 + "\r")
        sys.stdout.flush()
        print(f"    FAILED in {elapsed:.1f}s: {type(e).__name__}: {e}")
        failed.append((trial_name, f"{type(e).__name__}: {e}"))

batch_elapsed = time.time() - batch_started
print()
print(f"Batch done in {batch_elapsed:.1f}s (ok={len(all_summaries)}, failed={len(failed)})")
# Out:
# Run configuration:
#   subtrial_name:        'riskfn5'
#   SPEED_MULTIPLIER:     1.000
#   risk source:          ground truth (wm.get_risk() per tick)
#   fixed_delta:          0.050 s/tick  (20.0 Hz physics)
#   image_stride:         5 ticks/frame  (4.00 Hz JSONL records)
#   max_steps_per_trial:  6000  (cap = 300.0 s sim time, <= 1200 JSONL frames)
#   finished=True   -> controller reported done before the cap (good)
#   finished=False  -> hit max_steps cap (raise MAX_STEPS_PER_TRIAL or make risk_speed_fn faster)
#
# >>> [1/20] auto_17A_WetNoon_Town05_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step  1950/6000 ( 32.5% of cap)  wall=01:38  rate= 19.7 t/s  speedup=0.99x  eta_to_cap=03:25     Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in   99.7s wall  frames= 395  sim_t=  98.8s  speedup= 0.99x  dist=  548.3m  risk_auc=253.178  finished=True
#
# >>> [2/20] auto_17B_WetNoon_Town05_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step   700/6000 ( 11.7% of cap)  wall= 20.2s  rate= 34.7 t/s  speedup=1.74x  eta_to_cap=02:32    Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   20.3s wall  frames= 141  sim_t=  35.2s  speedup= 1.74x  dist=  557.9m  risk_auc=63.310  finished=True
#
# >>> [3/20] auto_17C_WetNoon_Town10HD_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step  1250/6000 ( 20.8% of cap)  wall= 50.9s  rate= 24.5 t/s  speedup=1.23x  eta_to_cap=03:13    Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in   51.1s wall  frames= 251  sim_t=  62.8s  speedup= 1.23x  dist=  160.2m  risk_auc=162.626  finished=True
#
# >>> [4/20] auto_17D_WetNoon_Town10HD_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  3225/6000 ( 53.8% of cap)  wall=01:08  rate= 47.0 t/s  speedup=2.35x  eta_to_cap= 59.0s    Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   68.8s wall  frames= 646  sim_t= 161.5s  speedup= 2.35x  dist=  423.9m  risk_auc=366.264  finished=True
#
# >>> [5/20] auto_18A_MidRainyNoon_Town05_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step  5600/6000 ( 93.3% of cap)  wall=03:18  rate= 28.2 t/s  speedup=1.41x  eta_to_cap= 14.2s    Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  198.8s wall  frames=1123  sim_t= 280.8s  speedup= 1.41x  dist=  951.0m  risk_auc=1205.085  finished=True
#
# >>> [6/20] auto_18B_MidRainyNoon_Town05_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step  1925/6000 ( 32.1% of cap)  wall= 44.7s  rate= 43.1 t/s  speedup=2.15x  eta_to_cap=01:34    Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   45.0s wall  frames= 389  sim_t=  97.3s  speedup= 2.16x  dist=  374.8m  risk_auc=521.368  finished=True
#
# >>> [7/20] auto_18C_MidRainyNoon_Town10HD_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step  4350/6000 ( 72.5% of cap)  wall=02:32  rate= 28.5 t/s  speedup=1.43x  eta_to_cap= 57.8s    Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  153.2s wall  frames= 875  sim_t= 218.8s  speedup= 1.43x  dist=  215.7m  risk_auc=599.100  finished=True
#
# >>> [8/20] auto_18D_MidRainyNoon_Town10HD_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  1925/6000 ( 32.1% of cap)  wall= 43.8s  rate= 43.9 t/s  speedup=2.20x  eta_to_cap=01:32    Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   44.1s wall  frames= 388  sim_t=  97.0s  speedup= 2.20x  dist=  312.8m  risk_auc=381.052  finished=True
#
# >>> [9/20] auto_19A_CloudySunset_Town05_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step   975/6000 ( 16.2% of cap)  wall= 39.1s  rate= 24.9 t/s  speedup=1.25x  eta_to_cap=03:21    Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in   39.7s wall  frames= 199  sim_t=  49.8s  speedup= 1.25x  dist=  152.8m  risk_auc=118.369  finished=True
#
# >>> [10/20] auto_19B_CloudySunset_Town05_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step  3900/6000 ( 65.0% of cap)  wall=01:17  rate= 50.3 t/s  speedup=2.51x  eta_to_cap= 41.8s    Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   78.1s wall  frames= 785  sim_t= 196.2s  speedup= 2.51x  dist=  862.3m  risk_auc=453.858  finished=True
#
# >>> [11/20] auto_19C_CloudySunset_Town10HD_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step  3950/6000 ( 65.8% of cap)  wall=02:23  rate= 27.5 t/s  speedup=1.38x  eta_to_cap=01:14     Tailgating, moving to the right!
# Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  144.4s wall  frames= 795  sim_t= 198.8s  speedup= 1.38x  dist=  559.2m  risk_auc=643.727  finished=True
#
# >>> [12/20] auto_19D_CloudySunset_Town10HD_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  1450/6000 ( 24.2% of cap)  wall= 39.1s  rate= 37.1 t/s  speedup=1.86x  eta_to_cap=02:02    Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   39.3s wall  frames= 293  sim_t=  73.2s  speedup= 1.86x  dist=  324.7m  risk_auc=192.309  finished=True
#
# >>> [13/20] auto_20A_SoftRainSunset_Town05_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step  4250/6000 ( 70.8% of cap)  wall=02:47  rate= 25.4 t/s  speedup=1.27x  eta_to_cap=01:08     Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  167.7s wall  frames= 852  sim_t= 213.0s  speedup= 1.27x  dist=  479.5m  risk_auc=729.253  finished=True
#
# >>> [14/20] auto_20B_SoftRainSunset_Town05_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step  3950/6000 ( 65.8% of cap)  wall=01:28  rate= 44.6 t/s  speedup=2.23x  eta_to_cap= 46.0s    Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   89.2s wall  frames= 795  sim_t= 198.8s  speedup= 2.23x  dist=  993.8m  risk_auc=506.599  finished=True
#
# >>> [15/20] auto_20C_SoftRainSunset_Town10HD_HighVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step  3225/6000 ( 53.8% of cap)  wall=02:03  rate= 26.2 t/s  speedup=1.31x  eta_to_cap=01:46     Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  123.8s wall  frames= 647  sim_t= 161.8s  speedup= 1.31x  dist=  720.9m  risk_auc=774.160  finished=True
#
# >>> [16/20] auto_20D_SoftRainSunset_Town10HD_LowVol
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=False)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  3225/6000 ( 53.8% of cap)  wall=01:12  rate= 44.6 t/s  speedup=2.23x  eta_to_cap=01:02     Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   72.6s wall  frames= 648  sim_t= 162.0s  speedup= 2.23x  dist=  669.0m  risk_auc=475.963  finished=True
#
# >>> [17/20] auto_21A_ClearNoon_Town05_HighVol_NoFog_Night
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=True)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 32 / 50 requested pedestrians.
#     step  5975/6000 ( 99.6% of cap)  wall=04:09  rate= 24.0 t/s  speedup=1.20x  eta_to_cap=  1.0s    Destroyed 64 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in  250.5s wall  frames=1200  sim_t= 300.0s  speedup= 1.20x  dist=  945.9m  risk_auc=631.260  finished=False
#
# >>> [18/20] auto_21B_CloudyNoon_Town05_LowVol_NoFog_Night
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=True)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# Spawned 14 / 20 requested pedestrians.
#     step  2550/6000 ( 42.5% of cap)  wall=01:21  rate= 31.2 t/s  speedup=1.56x  eta_to_cap=01:50     Destroyed 28 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   82.1s wall  frames= 513  sim_t= 128.2s  speedup= 1.56x  dist=  260.0m  risk_auc=266.799  finished=True
#
# >>> [19/20] auto_21C_WetNoon_Town10HD_HighVol_NoFog_Night
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=True)
# Spawned 80 / 80 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 49 / 50 requested pedestrians.
#     step  1025/6000 ( 17.1% of cap)  wall= 51.7s  rate= 19.8 t/s  speedup=0.99x  eta_to_cap=04:10    Destroyed 98 walker actors.
# Destroyed 80 vehicles.
# Destroyed ego vehicle.
#     ok in   52.6s wall  frames= 209  sim_t=  52.3s  speedup= 0.99x  dist=  270.6m  risk_auc=183.931  finished=True
#
# >>> [20/20] auto_21D_HardRainNoon_Town10HD_LowVol_NoFog_Night
# Spawned ego vehicle 'vehicle.lincoln.mkz_2020' at index None (autopilot=False, tm_lights=True)
# Spawned 40 / 40 requested vehicles.
# ERROR: Spawn failed because of collision at spawn position
# Spawned 19 / 20 requested pedestrians.
#     step  2900/6000 ( 48.3% of cap)  wall=01:36  rate= 30.1 t/s  speedup=1.51x  eta_to_cap=01:42     Destroyed 38 walker actors.
# Destroyed 40 vehicles.
# Destroyed ego vehicle.
#     ok in   97.1s wall  frames= 585  sim_t= 146.2s  speedup= 1.51x  dist=  443.0m  risk_auc=749.116  finished=True
#
# Batch done in 1918.1s (ok=20, failed=0)

# %% [markdown]
# ## 5 — Summary

# %%
if not all_summaries and not failed:
    print("No trials were run.")
else:
    print(f"=== Successful runs ({len(all_summaries)}) ===")
    print(
        f"  {'trial_name':50s} {'frames':>6s} {'dist_m':>9s} "
        f"{'risk_auc':>9s} {'risk/m':>9s}  finished  run_path"
    )
    for s in all_summaries:
        print(
            f"  {s.trial_name:50s} {s.num_frames:6d} {s.traveled_m:9.1f} "
            f"{s.risk_auc:9.3f} {s.risk_per_meter:9.5f}  {str(s.finished):>8s}  {s.run_path}"
        )

    if failed:
        print()
        print(f"=== Failed runs ({len(failed)}) ===")
        for name, err in failed:
            print(f"  {name}: {err}")
# Out:
# === Successful runs (20) ===
#   trial_name                                         frames    dist_m  risk_auc    risk/m  finished  run_path
#   auto_17A_WetNoon_Town05_HighVol                       395     548.3   253.178   2.51524      True  t:\TFG\MIREIA\trials\auto_17A_WetNoon_Town05_HighVol\runs\20260515_110815_riskfn5
#   auto_17B_WetNoon_Town05_LowVol                        141     557.9    63.310   1.97537      True  t:\TFG\MIREIA\trials\auto_17B_WetNoon_Town05_LowVol\runs\20260515_110955_riskfn5
#   auto_17C_WetNoon_Town10HD_HighVol                     251     160.2   162.626   3.65193      True  t:\TFG\MIREIA\trials\auto_17C_WetNoon_Town10HD_HighVol\runs\20260515_111015_riskfn5
#   auto_17D_WetNoon_Town10HD_LowVol                      646     423.9   366.264   3.31636      True  t:\TFG\MIREIA\trials\auto_17D_WetNoon_Town10HD_LowVol\runs\20260515_111107_riskfn5
#   auto_18A_MidRainyNoon_Town05_HighVol                 1123     951.0  1205.085   4.39964      True  t:\TFG\MIREIA\trials\auto_18A_MidRainyNoon_Town05_HighVol\runs\20260515_111215_riskfn5
#   auto_18B_MidRainyNoon_Town05_LowVol                   389     374.8   521.368   5.85284      True  t:\TFG\MIREIA\trials\auto_18B_MidRainyNoon_Town05_LowVol\runs\20260515_111534_riskfn5
#   auto_18C_MidRainyNoon_Town10HD_HighVol                875     215.7   599.100   6.76255      True  t:\TFG\MIREIA\trials\auto_18C_MidRainyNoon_Town10HD_HighVol\runs\20260515_111619_riskfn5
#   auto_18D_MidRainyNoon_Town10HD_LowVol                 388     312.8   381.052   4.73307      True  t:\TFG\MIREIA\trials\auto_18D_MidRainyNoon_Town10HD_LowVol\runs\20260515_111852_riskfn5
#   auto_19A_CloudySunset_Town05_HighVol                  199     152.8   118.369   3.29752      True  t:\TFG\MIREIA\trials\auto_19A_CloudySunset_Town05_HighVol\runs\20260515_111937_riskfn5
#   auto_19B_CloudySunset_Town05_LowVol                   785     862.3   453.858   2.47964      True  t:\TFG\MIREIA\trials\auto_19B_CloudySunset_Town05_LowVol\runs\20260515_112016_riskfn5
#   auto_19C_CloudySunset_Town10HD_HighVol                795     559.2   643.727   3.96836      True  t:\TFG\MIREIA\trials\auto_19C_CloudySunset_Town10HD_HighVol\runs\20260515_112134_riskfn5
#   auto_19D_CloudySunset_Town10HD_LowVol                 293     324.7   192.309   2.88776      True  t:\TFG\MIREIA\trials\auto_19D_CloudySunset_Town10HD_LowVol\runs\20260515_112359_riskfn5
#   auto_20A_SoftRainSunset_Town05_HighVol                852     479.5   729.253   4.56608      True  t:\TFG\MIREIA\trials\auto_20A_SoftRainSunset_Town05_HighVol\runs\20260515_112438_riskfn5
#   auto_20B_SoftRainSunset_Town05_LowVol                 795     993.8   506.599   2.49025      True  t:\TFG\MIREIA\trials\auto_20B_SoftRainSunset_Town05_LowVol\runs\20260515_112726_riskfn5
#   auto_20C_SoftRainSunset_Town10HD_HighVol              647     720.9   774.160   4.70982      True  t:\TFG\MIREIA\trials\auto_20C_SoftRainSunset_Town10HD_HighVol\runs\20260515_112855_riskfn5
#   auto_20D_SoftRainSunset_Town10HD_LowVol               648     669.0   475.963   3.43862      True  t:\TFG\MIREIA\trials\auto_20D_SoftRainSunset_Town10HD_LowVol\runs\20260515_113059_riskfn5
#   auto_21A_ClearNoon_Town05_HighVol_NoFog_Night        1200     945.9   631.260   1.99321     False  t:\TFG\MIREIA\trials\auto_21A_ClearNoon_Town05_HighVol_NoFog_Night\runs\20260515_113211_riskfn5
#   auto_21B_CloudyNoon_Town05_LowVol_NoFog_Night         513     260.0   266.799   3.52898      True  t:\TFG\MIREIA\trials\auto_21B_CloudyNoon_Town05_LowVol_NoFog_Night\runs\20260515_113622_riskfn5
#   auto_21C_WetNoon_Town10HD_HighVol_NoFog_Night         209     270.6   183.931   3.59438      True  t:\TFG\MIREIA\trials\auto_21C_WetNoon_Town10HD_HighVol_NoFog_Night\runs\20260515_113744_riskfn5
#   auto_21D_HardRainNoon_Town10HD_LowVol_NoFog_Night     585     443.0   749.116   5.99976      True  t:\TFG\MIREIA\trials\auto_21D_HardRainNoon_Town10HD_LowVol_NoFog_Night\runs\20260515_113836_riskfn5
